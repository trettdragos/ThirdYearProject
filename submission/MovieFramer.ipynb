# %%
import cv2
import numpy as np
import torch
from torchvision import transforms
from torch import nn
import time

VIDEOS_LOCATION = "C:\\Users\\trett\Documents\GitHub\ThirdYearProject\pytorch\\videos\\"

transform = transforms.ToTensor()

width = 640
height = 360

# %%
VIDEOS_LOCATION = "C:\\Users\\trett\Documents\GitHub\ThirdYearProject\pytorch\\videos\\"
VIDEOS_TRAIN = [
    {
        "file": "soldiers.mp4",
        "fps": None
    },
    {
        "file": 'running.mp4',
        "fps": None
    }
]

VIDEOS_TEST = [
    {
        "file": 'nato.mp4',
        "fps": None
    }
]

VIDEOS_SKI_TRAIN = [
    {
        "file": 'drone_shot.mp4',
        "fps": None
    },
    {
        "file": "crevace2.mp4",
        "fps": None
    }
]

VIDEOS_SKI_TEST = [
    {
        "file": "powder_maybe2.mp4",
        "fps": None
    }
]

class VideoDataLoader:
    video_index = 0
    videos = None
    cap = None
    frame_batch_buffer = []
    first_frame = None
    def __init__(self, videos):
        self.videos = videos
        self.cap = cv2.VideoCapture(VIDEOS_LOCATION + self.videos[self.video_index]["file"])
        self.videos[self.video_index]["fps"] = self.cap.get(cv2.CAP_PROP_FPS)
        if not self.cap.isOpened():
            print("Error: could not open video file")
        ret, first_frame = self.cap.read()
        for i in range(10):
            ret, middle_frame = self.cap.read()
            if not ret:
                break
            ret, last_frame = self.cap.read()
            if not ret:
                break
            batch_of_frames = [transform(first_frame), transform(middle_frame), transform(last_frame)]
            self.frame_batch_buffer.append(batch_of_frames)
            first_frame = last_frame
        self.first_frame = first_frame

    def hasNext(self):
        return len(self.frame_batch_buffer) != 0

    def nextFile(self):
        self.video_index += 1
        self.cap.release()
        try:
            self.cap = cv2.VideoCapture(VIDEOS_LOCATION + self.videos[self.video_index]["file"])
        except:
            batch = self.frame_batch_buffer.pop(0)
            self.frame_batch_buffer = []
            return batch

        self.videos[self.video_index]["fps"] = self.cap.get(cv2.CAP_PROP_FPS)
        if not self.cap.isOpened():
            print("Error: could not open video file")
        ret, first_frame = self.cap.read()
        for i in range(10):
            ret, middle_frame = self.cap.read()
            if not ret:
                break
            ret, last_frame = self.cap.read()
            if not ret:
                break
            batch_of_frames = [transform(first_frame), transform(middle_frame), transform(last_frame)]
            self.frame_batch_buffer.append(batch_of_frames)
            first_frame = last_frame
        self.first_frame = first_frame
        return self.frame_batch_buffer.pop(0)

    def getNext(self):
        if len(self.frame_batch_buffer) < 5:
            return self.nextFile()
        ret, middle_frame = self.cap.read()
        if not ret:
            return self.nextFile()
        ret, last_frame = self.cap.read()
        if not ret:
            return self.nextFile()

        batch_of_frames = [transform(self.first_frame), transform(middle_frame), transform(last_frame)]
        # batch_of_frames = [self.first_frame, middle_frame, last_frame]
        self.frame_batch_buffer.append(batch_of_frames)
        self.first_frame = last_frame
        # cv2.imshow('batch_of_frames', middle_frame)
        # cv2.imshow('batch_of_frames', last_frame)
        # if cv2.waitKey(25) & 0xFF == ord('q'):
        #     cv2.destroyAllWindows()
        #     self.frame_batch_buffer = []
        return self.frame_batch_buffer.pop(0)

# %%
class Autoencoder(nn.Module):

    def __init__(self):
        super().__init__()

        self.lefthand_encoder = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(in_channels=64, out_channels=16, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True)
        )

        self.righthand_encoder = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(in_channels=64, out_channels=16, kernel_size=3, stride=2, padding=1),
            nn.ReLU(True)
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(in_channels=32, out_channels=16, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(in_channels=16, out_channels=64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(in_channels=64, out_channels=3, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(True)
        )


    def forward(self, left, right):
        left = self.lefthand_encoder(left)
        right = self.lefthand_encoder(right)
        encoded = torch.cat((left, right), 0)
        x = self.decoder(encoded)
        return x

# %%
loss_fn = torch.nn.MSELoss()
lr= 0.0001
# torch.manual_seed(0)
autoencoder = Autoencoder()
params_to_optimize = [
    {'params': autoencoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-08)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

autoencoder = autoencoder.to(device)
# Out:
# Selected device: cuda

# %%
autoencoder.train()
epochs = 5
train_loss_epochs = []
for i in range(epochs):
    train_loss = []
    start = time.time()
    videoDataLoader = VideoDataLoader(VIDEOS_TRAIN)
    while videoDataLoader.hasNext():
        batch = videoDataLoader.getNext()
        first_frame = batch[0].to(device)
        middle_frame = batch[1].to(device)
        last_frame = batch[2].to(device)

        res_frame = autoencoder(first_frame, last_frame)
        # image_np = torchvision.transforms.functional.invert(res_frame.cpu().data).numpy()

        # Evaluate loss
        loss = loss_fn(res_frame, middle_frame)
        # Backward pass
        optim.zero_grad()
        loss.backward()
        optim.step()
        # Print batch loss
        print('\t %d partial train loss (single batch): %f' % (i, loss.data))
        train_loss.append(loss.detach().cpu().numpy())
    train_loss_epochs.append(train_loss)
# Out:
# 	 0 partial train loss (single batch): 0.238477
# 	 0 partial train loss (single batch): 0.237833
# 	 0 partial train loss (single batch): 0.237531
# 	 0 partial train loss (single batch): 0.237068
# 	 0 partial train loss (single batch): 0.236734
# 	 0 partial train loss (single batch): 0.236251
# 	 0 partial train loss (single batch): 0.235790
# 	 0 partial train loss (single batch): 0.235126
# 	 0 partial train loss (single batch): 0.234466
# 	 0 partial train loss (single batch): 0.233775
# 	 0 partial train loss (single batch): 0.233368
# 	 0 partial train loss (single batch): 0.232657
# 	 0 partial train loss (single batch): 0.232327
# 	 0 partial train loss (single batch): 0.231742
# 	 0 partial train loss (single batch): 0.231298
# 	 0 partial train loss (single batch): 0.230579
# 	 0 partial train loss (single batch): 0.230434
# 	 0 partial train loss (single batch): 0.230080
# 	 0 partial train loss (single batch): 0.229541
# 	 0 partial train loss (single batch): 0.228697
# 	 0 partial train loss (single batch): 0.227585
# 	 0 partial train loss (single batch): 0.226804
# 	 0 partial train loss (single batch): 0.226226
# 	 0 partial train loss (single batch): 0.225390
# 	 0 partial train loss (single batch): 0.224628
# 	 0 partial train loss (single batch): 0.223711
# 	 0 partial train loss (single batch): 0.222907
# 	 0 partial train loss (single batch): 0.221855
# 	 0 partial train loss (single batch): 0.220872
# 	 0 partial train loss (single batch): 0.219464
# 	 0 partial train loss (single batch): 0.218164
# 	 0 partial train loss (single batch): 0.216497
# 	 0 partial train loss (single batch): 0.214786
# 	 0 partial train loss (single batch): 0.212794
# 	 0 partial train loss (single batch): 0.210648
# 	 0 partial train loss (single batch): 0.208168
# 	 0 partial train loss (single batch): 0.205577
# 	 0 partial train loss (single batch): 0.202578
# 	 0 partial train loss (single batch): 0.199362
# 	 0 partial train loss (single batch): 0.195759
# 	 0 partial train loss (single batch): 0.191944
# 	 0 partial train loss (single batch): 0.187729
# 	 0 partial train loss (single batch): 0.183352
# 	 0 partial train loss (single batch): 0.178551
# 	 0 partial train loss (single batch): 0.173208
# 	 0 partial train loss (single batch): 0.167880
# 	 0 partial train loss (single batch): 0.162183
# 	 0 partial train loss (single batch): 0.156364
# 	 0 partial train loss (single batch): 0.150297
# 	 0 partial train loss (single batch): 0.144361
# 	 0 partial train loss (single batch): 0.138452
# 	 0 partial train loss (single batch): 0.132851
# 	 0 partial train loss (single batch): 0.127591
# 	 0 partial train loss (single batch): 0.122871
# 	 0 partial train loss (single batch): 0.118770
# 	 0 partial train loss (single batch): 0.115484
# 	 0 partial train loss (single batch): 0.112843
# 	 0 partial train loss (single batch): 0.110984
# 	 0 partial train loss (single batch): 0.109730
# 	 0 partial train loss (single batch): 0.108836
# 	 0 partial train loss (single batch): 0.107999
# 	 0 partial train loss (single batch): 0.106981
# 	 0 partial train loss (single batch): 0.105548
# 	 0 partial train loss (single batch): 0.103726
# 	 0 partial train loss (single batch): 0.101590
# 	 0 partial train loss (single batch): 0.099344
# 	 0 partial train loss (single batch): 0.097062
# 	 0 partial train loss (single batch): 0.094941
# 	 0 partial train loss (single batch): 0.092873
# 	 0 partial train loss (single batch): 0.091062
# 	 0 partial train loss (single batch): 0.089579
# 	 0 partial train loss (single batch): 0.088289
# 	 0 partial train loss (single batch): 0.087136
# 	 0 partial train loss (single batch): 0.086264
# 	 0 partial train loss (single batch): 0.085403
# 	 0 partial train loss (single batch): 0.084558
# 	 0 partial train loss (single batch): 0.083715
# 	 0 partial train loss (single batch): 0.082921
# 	 0 partial train loss (single batch): 0.082051
# 	 0 partial train loss (single batch): 0.081272
# 	 0 partial train loss (single batch): 0.080370
# 	 0 partial train loss (single batch): 0.079517
# 	 0 partial train loss (single batch): 0.078664
# 	 0 partial train loss (single batch): 0.077876
# 	 0 partial train loss (single batch): 0.077105
# 	 0 partial train loss (single batch): 0.076411
# 	 0 partial train loss (single batch): 0.075718
# 	 0 partial train loss (single batch): 0.075094
# 	 0 partial train loss (single batch): 0.074405
# 	 0 partial train loss (single batch): 0.073399
# 	 0 partial train loss (single batch): 0.072693
# 	 0 partial train loss (single batch): 0.072149
# 	 0 partial train loss (single batch): 0.071596
# 	 0 partial train loss (single batch): 0.071024
# 	 0 partial train loss (single batch): 0.070494
# 	 0 partial train loss (single batch): 0.069921
# 	 0 partial train loss (single batch): 0.069411
# 	 0 partial train loss (single batch): 0.068940
# 	 0 partial train loss (single batch): 0.068499
# 	 0 partial train loss (single batch): 0.068065
# 	 0 partial train loss (single batch): 0.067668
# 	 0 partial train loss (single batch): 0.067270
# 	 0 partial train loss (single batch): 0.066918
# 	 0 partial train loss (single batch): 0.066529
# 	 0 partial train loss (single batch): 0.065923
# 	 0 partial train loss (single batch): 0.065511
# 	 0 partial train loss (single batch): 0.065002
# 	 0 partial train loss (single batch): 0.064601
# 	 0 partial train loss (single batch): 0.064131
# 	 0 partial train loss (single batch): 0.063779
# 	 0 partial train loss (single batch): 0.063313
# 	 0 partial train loss (single batch): 0.062555
# 	 0 partial train loss (single batch): 0.062188
# 	 0 partial train loss (single batch): 0.061611
# 	 0 partial train loss (single batch): 0.060711
# 	 0 partial train loss (single batch): 0.060384
# 	 0 partial train loss (single batch): 0.060205
# 	 0 partial train loss (single batch): 0.059996
# 	 0 partial train loss (single batch): 0.060026
# 	 0 partial train loss (single batch): 0.060120
# 	 0 partial train loss (single batch): 0.059981
# 	 0 partial train loss (single batch): 0.059799
# 	 0 partial train loss (single batch): 0.059681
# 	 0 partial train loss (single batch): 0.059527
# 	 0 partial train loss (single batch): 0.059407
# 	 0 partial train loss (single batch): 0.059212
# 	 0 partial train loss (single batch): 0.059122
# 	 0 partial train loss (single batch): 0.058982
# 	 0 partial train loss (single batch): 0.058878
# 	 0 partial train loss (single batch): 0.058718
# 	 0 partial train loss (single batch): 0.058640
# 	 0 partial train loss (single batch): 0.058489
# 	 0 partial train loss (single batch): 0.058343
# 	 0 partial train loss (single batch): 0.058129
# 	 0 partial train loss (single batch): 0.057991
# 	 0 partial train loss (single batch): 0.057762
# 	 0 partial train loss (single batch): 0.057592
# 	 0 partial train loss (single batch): 0.057442
# 	 0 partial train loss (single batch): 0.057259
# 	 0 partial train loss (single batch): 0.057061
# 	 0 partial train loss (single batch): 0.056780
# 	 0 partial train loss (single batch): 0.056627
# 	 0 partial train loss (single batch): 0.056410
# 	 0 partial train loss (single batch): 0.056210
# 	 0 partial train loss (single batch): 0.055830
# 	 0 partial train loss (single batch): 0.055573
# 	 0 partial train loss (single batch): 0.055264
# 	 0 partial train loss (single batch): 0.054798
# 	 0 partial train loss (single batch): 0.054221
# 	 0 partial train loss (single batch): 0.053401
# 	 0 partial train loss (single batch): 0.052944
# 	 0 partial train loss (single batch): 0.052511
# 	 0 partial train loss (single batch): 0.051885
# 	 0 partial train loss (single batch): 0.051169
# 	 0 partial train loss (single batch): 0.050624
# 	 0 partial train loss (single batch): 0.050105
# 	 0 partial train loss (single batch): 0.049496
# 	 0 partial train loss (single batch): 0.049133
# 	 0 partial train loss (single batch): 0.048722
# 	 0 partial train loss (single batch): 0.048392
# 	 0 partial train loss (single batch): 0.047983
# 	 0 partial train loss (single batch): 0.047654
# 	 0 partial train loss (single batch): 0.047233
# 	 0 partial train loss (single batch): 0.046877
# 	 0 partial train loss (single batch): 0.046463
# 	 0 partial train loss (single batch): 0.046096
# 	 0 partial train loss (single batch): 0.045700
# 	 0 partial train loss (single batch): 0.045341
# 	 0 partial train loss (single batch): 0.044941
# 	 0 partial train loss (single batch): 0.044587
# 	 0 partial train loss (single batch): 0.044218
# 	 0 partial train loss (single batch): 0.043887
# 	 0 partial train loss (single batch): 0.043521
# 	 0 partial train loss (single batch): 0.043171
# 	 0 partial train loss (single batch): 0.042757
# 	 0 partial train loss (single batch): 0.042331
# 	 0 partial train loss (single batch): 0.041865
# 	 0 partial train loss (single batch): 0.041457
# 	 0 partial train loss (single batch): 0.040983
# 	 0 partial train loss (single batch): 0.040489
# 	 0 partial train loss (single batch): 0.040035
# 	 0 partial train loss (single batch): 0.039567
# 	 0 partial train loss (single batch): 0.039144
# 	 0 partial train loss (single batch): 0.038707
# 	 0 partial train loss (single batch): 0.038305
# 	 0 partial train loss (single batch): 0.037884
# 	 0 partial train loss (single batch): 0.037485
# 	 0 partial train loss (single batch): 0.037042
# 	 0 partial train loss (single batch): 0.036615
# 	 0 partial train loss (single batch): 0.036131
# 	 0 partial train loss (single batch): 0.035646
# 	 0 partial train loss (single batch): 0.035118
# 	 0 partial train loss (single batch): 0.034578
# 	 0 partial train loss (single batch): 0.034037
# 	 0 partial train loss (single batch): 0.033537
# 	 0 partial train loss (single batch): 0.033043
# 	 0 partial train loss (single batch): 0.032563
# 	 0 partial train loss (single batch): 0.032071
# 	 0 partial train loss (single batch): 0.031550
# 	 0 partial train loss (single batch): 0.031023
# 	 0 partial train loss (single batch): 0.030543
# 	 0 partial train loss (single batch): 0.030056
# 	 0 partial train loss (single batch): 0.029621
# 	 0 partial train loss (single batch): 0.029175
# 	 0 partial train loss (single batch): 0.028719
# 	 0 partial train loss (single batch): 0.028280
# 	 0 partial train loss (single batch): 0.027875
# 	 0 partial train loss (single batch): 0.027458
# 	 0 partial train loss (single batch): 0.027059
# 	 0 partial train loss (single batch): 0.026636
# 	 0 partial train loss (single batch): 0.026225
# 	 0 partial train loss (single batch): 0.025838
# 	 0 partial train loss (single batch): 0.025458
# 	 0 partial train loss (single batch): 0.025109
# 	 0 partial train loss (single batch): 0.024777
# 	 0 partial train loss (single batch): 0.024469
# 	 0 partial train loss (single batch): 0.024153
# 	 0 partial train loss (single batch): 0.023844
# 	 0 partial train loss (single batch): 0.023553
# 	 0 partial train loss (single batch): 0.023288
# 	 0 partial train loss (single batch): 0.023030
# 	 0 partial train loss (single batch): 0.022780
# 	 0 partial train loss (single batch): 0.022523
# 	 0 partial train loss (single batch): 0.022286
# 	 0 partial train loss (single batch): 0.022061
# 	 0 partial train loss (single batch): 0.021831
# 	 0 partial train loss (single batch): 0.021631
# 	 0 partial train loss (single batch): 0.021437
# 	 0 partial train loss (single batch): 0.030903
# 	 0 partial train loss (single batch): 0.026323
# 	 0 partial train loss (single batch): 0.025921
# 	 0 partial train loss (single batch): 0.025157
# 	 0 partial train loss (single batch): 0.024107
# 	 0 partial train loss (single batch): 0.023018
# 	 0 partial train loss (single batch): 0.022005
# 	 0 partial train loss (single batch): 0.021138
# 	 0 partial train loss (single batch): 0.020453
# 	 0 partial train loss (single batch): 0.019831
# 	 0 partial train loss (single batch): 0.019401
# 	 0 partial train loss (single batch): 0.018968
# 	 0 partial train loss (single batch): 0.018621
# 	 0 partial train loss (single batch): 0.018236
# 	 0 partial train loss (single batch): 0.017875
# 	 0 partial train loss (single batch): 0.017474
# 	 0 partial train loss (single batch): 0.017212
# 	 0 partial train loss (single batch): 0.016930
# 	 0 partial train loss (single batch): 0.016753
# 	 0 partial train loss (single batch): 0.016490
# 	 0 partial train loss (single batch): 0.016367
# 	 0 partial train loss (single batch): 0.016185
# 	 0 partial train loss (single batch): 0.016100
# 	 0 partial train loss (single batch): 0.016007
# 	 0 partial train loss (single batch): 0.015880
# 	 0 partial train loss (single batch): 0.015844
# 	 0 partial train loss (single batch): 0.015718
# 	 0 partial train loss (single batch): 0.015578
# 	 0 partial train loss (single batch): 0.015505
# 	 0 partial train loss (single batch): 0.015343
# 	 0 partial train loss (single batch): 0.015308
# 	 0 partial train loss (single batch): 0.015203
# 	 0 partial train loss (single batch): 0.015202
# 	 0 partial train loss (single batch): 0.015069
# 	 0 partial train loss (single batch): 0.015034
# 	 0 partial train loss (single batch): 0.015007
# 	 0 partial train loss (single batch): 0.014948
# 	 0 partial train loss (single batch): 0.014994
# 	 0 partial train loss (single batch): 0.014945
# 	 0 partial train loss (single batch): 0.014927
# 	 0 partial train loss (single batch): 0.014836
# 	 0 partial train loss (single batch): 0.014847
# 	 0 partial train loss (single batch): 0.014838
# 	 0 partial train loss (single batch): 0.014854
# 	 0 partial train loss (single batch): 0.014816
# 	 0 partial train loss (single batch): 0.014799
# 	 0 partial train loss (single batch): 0.014808
# 	 0 partial train loss (single batch): 0.014744
# 	 0 partial train loss (single batch): 0.014691
# 	 0 partial train loss (single batch): 0.014714
# 	 0 partial train loss (single batch): 0.014661
# 	 0 partial train loss (single batch): 0.014590
# 	 0 partial train loss (single batch): 0.014545
# 	 0 partial train loss (single batch): 0.014451
# 	 0 partial train loss (single batch): 0.014380
# 	 0 partial train loss (single batch): 0.014396
# 	 0 partial train loss (single batch): 0.014378
# 	 0 partial train loss (single batch): 0.014316
# 	 0 partial train loss (single batch): 0.014308
# 	 0 partial train loss (single batch): 0.014236
# 	 0 partial train loss (single batch): 0.014114
# 	 0 partial train loss (single batch): 0.014069
# 	 0 partial train loss (single batch): 0.014009
# 	 0 partial train loss (single batch): 0.013891
# 	 0 partial train loss (single batch): 0.013854
# 	 0 partial train loss (single batch): 0.013773
# 	 0 partial train loss (single batch): 0.013693
# 	 0 partial train loss (single batch): 0.013657
# 	 0 partial train loss (single batch): 0.013563
# 	 0 partial train loss (single batch): 0.013455
# 	 0 partial train loss (single batch): 0.013365
# 	 0 partial train loss (single batch): 0.013227
# 	 0 partial train loss (single batch): 0.013066
# 	 0 partial train loss (single batch): 0.012906
# 	 0 partial train loss (single batch): 0.012784
# 	 0 partial train loss (single batch): 0.012687
# 	 0 partial train loss (single batch): 0.012632
# 	 0 partial train loss (single batch): 0.012491
# 	 0 partial train loss (single batch): 0.012425
# 	 0 partial train loss (single batch): 0.012412
# 	 0 partial train loss (single batch): 0.012329
# 	 0 partial train loss (single batch): 0.012255
# 	 0 partial train loss (single batch): 0.012141
# 	 0 partial train loss (single batch): 0.012009
# 	 0 partial train loss (single batch): 0.011830
# 	 0 partial train loss (single batch): 0.011713
# 	 0 partial train loss (single batch): 0.011621
# 	 0 partial train loss (single batch): 0.011460
# 	 0 partial train loss (single batch): 0.011362
# 	 0 partial train loss (single batch): 0.011184
# 	 0 partial train loss (single batch): 0.010978
# 	 0 partial train loss (single batch): 0.010857
# 	 0 partial train loss (single batch): 0.010739
# 	 0 partial train loss (single batch): 0.010592
# 	 0 partial train loss (single batch): 0.010482
# 	 0 partial train loss (single batch): 0.010348
# 	 0 partial train loss (single batch): 0.010115
# 	 0 partial train loss (single batch): 0.009967
# 	 0 partial train loss (single batch): 0.009861
# 	 0 partial train loss (single batch): 0.009747
# 	 0 partial train loss (single batch): 0.009750
# 	 0 partial train loss (single batch): 0.009704
# 	 0 partial train loss (single batch): 0.009551
# 	 0 partial train loss (single batch): 0.009495
# 	 0 partial train loss (single batch): 0.009461
# 	 0 partial train loss (single batch): 0.009381
# 	 0 partial train loss (single batch): 0.009387
# 	 0 partial train loss (single batch): 0.009329
# 	 0 partial train loss (single batch): 0.009221
# 	 0 partial train loss (single batch): 0.009153
# 	 0 partial train loss (single batch): 0.009075
# 	 0 partial train loss (single batch): 0.008964
# 	 0 partial train loss (single batch): 0.008957
# 	 0 partial train loss (single batch): 0.008892
# 	 0 partial train loss (single batch): 0.008851
# 	 0 partial train loss (single batch): 0.008762
# 	 0 partial train loss (single batch): 0.008733
# 	 0 partial train loss (single batch): 0.008659
# 	 0 partial train loss (single batch): 0.008588
# 	 0 partial train loss (single batch): 0.008543
# 	 0 partial train loss (single batch): 0.008498
# 	 0 partial train loss (single batch): 0.008454
# 	 0 partial train loss (single batch): 0.008373
# 	 0 partial train loss (single batch): 0.008292
# 	 0 partial train loss (single batch): 0.008215
# 	 0 partial train loss (single batch): 0.008181
# 	 0 partial train loss (single batch): 0.008153
# 	 0 partial train loss (single batch): 0.008031
# 	 0 partial train loss (single batch): 0.008016
# 	 0 partial train loss (single batch): 0.007980
# 	 0 partial train loss (single batch): 0.007942
# 	 0 partial train loss (single batch): 0.007973
# 	 0 partial train loss (single batch): 0.008001
# 	 0 partial train loss (single batch): 0.007995
# 	 0 partial train loss (single batch): 0.007880
# 	 0 partial train loss (single batch): 0.007752
# 	 0 partial train loss (single batch): 0.007669
# 	 0 partial train loss (single batch): 0.007650
# 	 0 partial train loss (single batch): 0.007571
# 	 0 partial train loss (single batch): 0.007516
# 	 0 partial train loss (single batch): 0.007442
# 	 0 partial train loss (single batch): 0.007296
# 	 0 partial train loss (single batch): 0.007280
# 	 0 partial train loss (single batch): 0.007238
# 	 0 partial train loss (single batch): 0.007201
# 	 0 partial train loss (single batch): 0.007196
# 	 0 partial train loss (single batch): 0.007211
# 	 0 partial train loss (single batch): 0.007052
# 	 0 partial train loss (single batch): 0.006999
# 	 0 partial train loss (single batch): 0.007003
# 	 0 partial train loss (single batch): 0.006976
# 	 0 partial train loss (single batch): 0.006951
# 	 0 partial train loss (single batch): 0.007010
# 	 0 partial train loss (single batch): 0.006922
# 	 0 partial train loss (single batch): 0.006846
# 	 0 partial train loss (single batch): 0.006834
# 	 0 partial train loss (single batch): 0.006827
# 	 0 partial train loss (single batch): 0.006839
# 	 0 partial train loss (single batch): 0.006846
# 	 0 partial train loss (single batch): 0.006753
# 	 0 partial train loss (single batch): 0.006704
# 	 0 partial train loss (single batch): 0.006674
# 	 0 partial train loss (single batch): 0.006652
# 	 0 partial train loss (single batch): 0.006615
# 	 0 partial train loss (single batch): 0.006585
# 	 0 partial train loss (single batch): 0.006569
# 	 0 partial train loss (single batch): 0.006505
# 	 0 partial train loss (single batch): 0.006476
# 	 0 partial train loss (single batch): 0.006456
# 	 0 partial train loss (single batch): 0.006431
# 	 0 partial train loss (single batch): 0.006449
# 	 0 partial train loss (single batch): 0.006417
# 	 0 partial train loss (single batch): 0.006398
# 	 0 partial train loss (single batch): 0.006394
# 	 0 partial train loss (single batch): 0.006343
# 	 0 partial train loss (single batch): 0.006265
# 	 0 partial train loss (single batch): 0.006351
# 	 0 partial train loss (single batch): 0.006339
# 	 0 partial train loss (single batch): 0.006430
# 	 0 partial train loss (single batch): 0.006316
# 	 0 partial train loss (single batch): 0.006272
# 	 0 partial train loss (single batch): 0.006197
# 	 0 partial train loss (single batch): 0.006223
# 	 0 partial train loss (single batch): 0.006244
# 	 0 partial train loss (single batch): 0.006254
# 	 0 partial train loss (single batch): 0.006251
# 	 0 partial train loss (single batch): 0.006203
# 	 0 partial train loss (single batch): 0.006127
# 	 0 partial train loss (single batch): 0.006118
# 	 0 partial train loss (single batch): 0.006154
# 	 0 partial train loss (single batch): 0.006135
# 	 0 partial train loss (single batch): 0.006136
# 	 0 partial train loss (single batch): 0.006044
# 	 0 partial train loss (single batch): 0.005988
# 	 0 partial train loss (single batch): 0.006039
# 	 0 partial train loss (single batch): 0.006016
# 	 0 partial train loss (single batch): 0.006022
# 	 0 partial train loss (single batch): 0.006051
# 	 0 partial train loss (single batch): 0.006041
# 	 0 partial train loss (single batch): 0.005945
# 	 0 partial train loss (single batch): 0.005941
# 	 0 partial train loss (single batch): 0.005974
# 	 0 partial train loss (single batch): 0.005867
# 	 0 partial train loss (single batch): 0.005982
# 	 0 partial train loss (single batch): 0.005977
# 	 0 partial train loss (single batch): 0.005905
# 	 0 partial train loss (single batch): 0.005825
# 	 0 partial train loss (single batch): 0.005842
# 	 0 partial train loss (single batch): 0.005862
# 	 0 partial train loss (single batch): 0.005834
# 	 0 partial train loss (single batch): 0.005873
# 	 0 partial train loss (single batch): 0.005887
# 	 0 partial train loss (single batch): 0.005853
# 	 0 partial train loss (single batch): 0.005770
# 	 0 partial train loss (single batch): 0.005808
# 	 0 partial train loss (single batch): 0.005795
# 	 0 partial train loss (single batch): 0.005842
# 	 0 partial train loss (single batch): 0.005881
# 	 0 partial train loss (single batch): 0.005914
# 	 0 partial train loss (single batch): 0.005875
# 	 0 partial train loss (single batch): 0.005794
# 	 0 partial train loss (single batch): 0.005825
# 	 0 partial train loss (single batch): 0.005814
# 	 0 partial train loss (single batch): 0.005907
# 	 0 partial train loss (single batch): 0.005857
# 	 0 partial train loss (single batch): 0.005780
# 	 0 partial train loss (single batch): 0.005710
# 	 0 partial train loss (single batch): 0.005711
# 	 0 partial train loss (single batch): 0.005733
# 	 0 partial train loss (single batch): 0.005716
# 	 0 partial train loss (single batch): 0.005780
# 	 0 partial train loss (single batch): 0.005715
# 	 0 partial train loss (single batch): 0.005636
# 	 0 partial train loss (single batch): 0.005584
# 	 0 partial train loss (single batch): 0.005655
# 	 0 partial train loss (single batch): 0.005609
# 	 0 partial train loss (single batch): 0.005720
# 	 0 partial train loss (single batch): 0.005652
# 	 0 partial train loss (single batch): 0.005713
# 	 0 partial train loss (single batch): 0.005602
# 	 0 partial train loss (single batch): 0.005587
# 	 0 partial train loss (single batch): 0.005666
# 	 0 partial train loss (single batch): 0.005671
# 	 0 partial train loss (single batch): 0.005658
# 	 0 partial train loss (single batch): 0.005619
# 	 0 partial train loss (single batch): 0.005573
# 	 0 partial train loss (single batch): 0.005545
# 	 0 partial train loss (single batch): 0.005518
# 	 0 partial train loss (single batch): 0.005549
# 	 0 partial train loss (single batch): 0.005630
# 	 0 partial train loss (single batch): 0.005573
# 	 0 partial train loss (single batch): 0.005552
# 	 0 partial train loss (single batch): 0.005530
# 	 0 partial train loss (single batch): 0.005562
# 	 0 partial train loss (single batch): 0.005590
# 	 0 partial train loss (single batch): 0.005586
# 	 0 partial train loss (single batch): 0.005589
# 	 0 partial train loss (single batch): 0.005547
# 	 0 partial train loss (single batch): 0.005462
# 	 0 partial train loss (single batch): 0.005447
# 	 0 partial train loss (single batch): 0.005469
# 	 0 partial train loss (single batch): 0.005479
# 	 0 partial train loss (single batch): 0.005565
# 	 0 partial train loss (single batch): 0.005611
# 	 0 partial train loss (single batch): 0.005546
# 	 0 partial train loss (single batch): 0.005521
# 	 0 partial train loss (single batch): 0.005640
# 	 0 partial train loss (single batch): 0.005610
# 	 0 partial train loss (single batch): 0.005614
# 	 0 partial train loss (single batch): 0.005645
# 	 0 partial train loss (single batch): 0.005703
# 	 0 partial train loss (single batch): 0.005651
# 	 0 partial train loss (single batch): 0.005529
# 	 0 partial train loss (single batch): 0.005549
# 	 0 partial train loss (single batch): 0.005596
# 	 0 partial train loss (single batch): 0.005636
# 	 0 partial train loss (single batch): 0.005666
# 	 0 partial train loss (single batch): 0.005657
# 	 0 partial train loss (single batch): 0.005488
# 	 0 partial train loss (single batch): 0.005441
# 	 0 partial train loss (single batch): 0.005492
# 	 0 partial train loss (single batch): 0.005500
# 	 0 partial train loss (single batch): 0.005543
# 	 0 partial train loss (single batch): 0.005592
# 	 0 partial train loss (single batch): 0.005539
# 	 0 partial train loss (single batch): 0.005335
# 	 0 partial train loss (single batch): 0.005298
# 	 0 partial train loss (single batch): 0.005421
# 	 0 partial train loss (single batch): 0.005446
# 	 0 partial train loss (single batch): 0.005526
# 	 0 partial train loss (single batch): 0.005538
# 	 0 partial train loss (single batch): 0.005452
# 	 0 partial train loss (single batch): 0.005301
# 	 0 partial train loss (single batch): 0.005344
# 	 0 partial train loss (single batch): 0.005370
# 	 0 partial train loss (single batch): 0.005457
# 	 0 partial train loss (single batch): 0.005512
# 	 0 partial train loss (single batch): 0.005453
# 	 0 partial train loss (single batch): 0.005291
# 	 0 partial train loss (single batch): 0.005277
# 	 0 partial train loss (single batch): 0.005320
# 	 0 partial train loss (single batch): 0.005303
# 	 0 partial train loss (single batch): 0.005477
# 	 0 partial train loss (single batch): 0.005398
# 	 0 partial train loss (single batch): 0.005317
# 	 0 partial train loss (single batch): 0.005208
# 	 0 partial train loss (single batch): 0.005262
# 	 0 partial train loss (single batch): 0.005249
# 	 0 partial train loss (single batch): 0.005340
# 	 0 partial train loss (single batch): 0.005344
# 	 0 partial train loss (single batch): 0.005362
# 	 0 partial train loss (single batch): 0.005287
# 	 0 partial train loss (single batch): 0.005340
# 	 0 partial train loss (single batch): 0.005379
# 	 0 partial train loss (single batch): 0.005405
# 	 0 partial train loss (single batch): 0.005446
# 	 0 partial train loss (single batch): 0.005401
# 	 0 partial train loss (single batch): 0.005429
# 	 0 partial train loss (single batch): 0.005249
# 	 0 partial train loss (single batch): 0.005366
# 	 0 partial train loss (single batch): 0.005414
# 	 0 partial train loss (single batch): 0.005432
# 	 0 partial train loss (single batch): 0.005498
# 	 0 partial train loss (single batch): 0.005498
# 	 0 partial train loss (single batch): 0.005508
# 	 0 partial train loss (single batch): 0.005385
# 	 0 partial train loss (single batch): 0.005532
# 	 0 partial train loss (single batch): 0.005396
# 	 0 partial train loss (single batch): 0.005450
# 	 0 partial train loss (single batch): 0.005464
# 	 0 partial train loss (single batch): 0.005456
# 	 0 partial train loss (single batch): 0.005244
# 	 0 partial train loss (single batch): 0.005339
# 	 0 partial train loss (single batch): 0.005380
# 	 0 partial train loss (single batch): 0.005406
# 	 0 partial train loss (single batch): 0.005377
# 	 0 partial train loss (single batch): 0.005437
# 	 0 partial train loss (single batch): 0.005361
# 	 0 partial train loss (single batch): 0.005297
# 	 0 partial train loss (single batch): 0.005417
# 	 0 partial train loss (single batch): 0.005396
# 	 0 partial train loss (single batch): 0.005404
# 	 0 partial train loss (single batch): 0.005354
# 	 0 partial train loss (single batch): 0.005528
# 	 0 partial train loss (single batch): 0.005237
# 	 0 partial train loss (single batch): 0.005257
# 	 0 partial train loss (single batch): 0.005382
# 	 0 partial train loss (single batch): 0.005411
# 	 0 partial train loss (single batch): 0.005381
# 	 0 partial train loss (single batch): 0.005400
# 	 0 partial train loss (single batch): 0.005414
# 	 0 partial train loss (single batch): 0.005304
# 	 0 partial train loss (single batch): 0.005331
# 	 0 partial train loss (single batch): 0.005400
# 	 0 partial train loss (single batch): 0.005475
# 	 0 partial train loss (single batch): 0.005434
# 	 0 partial train loss (single batch): 0.005480
# 	 0 partial train loss (single batch): 0.005454
# 	 0 partial train loss (single batch): 0.005351
# 	 0 partial train loss (single batch): 0.005385
# 	 0 partial train loss (single batch): 0.005431
# 	 0 partial train loss (single batch): 0.005441
# 	 0 partial train loss (single batch): 0.005420
# 	 0 partial train loss (single batch): 0.005404
# 	 0 partial train loss (single batch): 0.005354
# 	 0 partial train loss (single batch): 0.005276
# 	 0 partial train loss (single batch): 0.005349
# 	 0 partial train loss (single batch): 0.005370
# 	 0 partial train loss (single batch): 0.005444
# 	 0 partial train loss (single batch): 0.005364
# 	 0 partial train loss (single batch): 0.005394
# 	 0 partial train loss (single batch): 0.005282
# 	 0 partial train loss (single batch): 0.005265
# 	 0 partial train loss (single batch): 0.005293
# 	 0 partial train loss (single batch): 0.005346
# 	 0 partial train loss (single batch): 0.005309
# 	 0 partial train loss (single batch): 0.005271
# 	 0 partial train loss (single batch): 0.005249
# 	 0 partial train loss (single batch): 0.005187
# 	 0 partial train loss (single batch): 0.005287
# 	 0 partial train loss (single batch): 0.005321
# 	 0 partial train loss (single batch): 0.005344
# 	 0 partial train loss (single batch): 0.005272
# 	 0 partial train loss (single batch): 0.005356
# 	 0 partial train loss (single batch): 0.005166
# 	 0 partial train loss (single batch): 0.005148
# 	 0 partial train loss (single batch): 0.005247
# 	 0 partial train loss (single batch): 0.005271
# 	 0 partial train loss (single batch): 0.005223
# 	 0 partial train loss (single batch): 0.005217
# 	 0 partial train loss (single batch): 0.005221
# 	 0 partial train loss (single batch): 0.005106
# 	 0 partial train loss (single batch): 0.005223
# 	 0 partial train loss (single batch): 0.005225
# 	 0 partial train loss (single batch): 0.005277
# 	 0 partial train loss (single batch): 0.005223
# 	 0 partial train loss (single batch): 0.005271
# 	 0 partial train loss (single batch): 0.005106
# 	 0 partial train loss (single batch): 0.005141
# 	 0 partial train loss (single batch): 0.005192
# 	 0 partial train loss (single batch): 0.005228
# 	 0 partial train loss (single batch): 0.005257
# 	 0 partial train loss (single batch): 0.005287
# 	 0 partial train loss (single batch): 0.005334
# 	 0 partial train loss (single batch): 0.005353
# 	 0 partial train loss (single batch): 0.005205
# 	 0 partial train loss (single batch): 0.005262
# 	 0 partial train loss (single batch): 0.005296
# 	 0 partial train loss (single batch): 0.005263
# 	 0 partial train loss (single batch): 0.005251
# 	 0 partial train loss (single batch): 0.005179
# 	 0 partial train loss (single batch): 0.005172
# 	 0 partial train loss (single batch): 0.005203
# 	 0 partial train loss (single batch): 0.005195
# 	 0 partial train loss (single batch): 0.005267
# 	 0 partial train loss (single batch): 0.005248
# 	 0 partial train loss (single batch): 0.005333
# 	 0 partial train loss (single batch): 0.005135
# 	 0 partial train loss (single batch): 0.005153
# 	 0 partial train loss (single batch): 0.005208
# 	 0 partial train loss (single batch): 0.005235
# 	 0 partial train loss (single batch): 0.005244
# 	 0 partial train loss (single batch): 0.005136
# 	 0 partial train loss (single batch): 0.005232
# 	 0 partial train loss (single batch): 0.005103
# 	 0 partial train loss (single batch): 0.005064
# 	 0 partial train loss (single batch): 0.005047
# 	 0 partial train loss (single batch): 0.005159
# 	 0 partial train loss (single batch): 0.005066
# 	 0 partial train loss (single batch): 0.005075
# 	 0 partial train loss (single batch): 0.004996
# 	 0 partial train loss (single batch): 0.005027
# 	 0 partial train loss (single batch): 0.005003
# 	 0 partial train loss (single batch): 0.005118
# 	 0 partial train loss (single batch): 0.005044
# 	 0 partial train loss (single batch): 0.005068
# 	 0 partial train loss (single batch): 0.004926
# 	 0 partial train loss (single batch): 0.004949
# 	 0 partial train loss (single batch): 0.005024
# 	 0 partial train loss (single batch): 0.005005
# 	 0 partial train loss (single batch): 0.004986
# 	 0 partial train loss (single batch): 0.005049
# 	 0 partial train loss (single batch): 0.004965
# 	 0 partial train loss (single batch): 0.004868
# 	 0 partial train loss (single batch): 0.005014
# 	 0 partial train loss (single batch): 0.004989
# 	 0 partial train loss (single batch): 0.005022
# 	 0 partial train loss (single batch): 0.005035
# 	 0 partial train loss (single batch): 0.005123
# 	 0 partial train loss (single batch): 0.004923
# 	 0 partial train loss (single batch): 0.004950
# 	 0 partial train loss (single batch): 0.004987
# 	 0 partial train loss (single batch): 0.004984
# 	 0 partial train loss (single batch): 0.004970
# 	 0 partial train loss (single batch): 0.005030
# 	 0 partial train loss (single batch): 0.004976
# 	 0 partial train loss (single batch): 0.004852
# 	 0 partial train loss (single batch): 0.004939
# 	 0 partial train loss (single batch): 0.004953
# 	 0 partial train loss (single batch): 0.004950
# 	 0 partial train loss (single batch): 0.004901
# 	 0 partial train loss (single batch): 0.005001
# 	 0 partial train loss (single batch): 0.004841
# 	 0 partial train loss (single batch): 0.004747
# 	 0 partial train loss (single batch): 0.004739
# 	 0 partial train loss (single batch): 0.004814
# 	 0 partial train loss (single batch): 0.004837
# 	 0 partial train loss (single batch): 0.004780
# 	 0 partial train loss (single batch): 0.004863
# 	 0 partial train loss (single batch): 0.004736
# 	 0 partial train loss (single batch): 0.004756
# 	 0 partial train loss (single batch): 0.004737
# 	 0 partial train loss (single batch): 0.004815
# 	 0 partial train loss (single batch): 0.004797
# 	 0 partial train loss (single batch): 0.004784
# 	 0 partial train loss (single batch): 0.004700
# 	 0 partial train loss (single batch): 0.004662
# 	 0 partial train loss (single batch): 0.004649
# 	 0 partial train loss (single batch): 0.004726
# 	 0 partial train loss (single batch): 0.004726
# 	 0 partial train loss (single batch): 0.004628
# 	 0 partial train loss (single batch): 0.004676
# 	 0 partial train loss (single batch): 0.004594
# 	 0 partial train loss (single batch): 0.004647
# 	 0 partial train loss (single batch): 0.004599
# 	 0 partial train loss (single batch): 0.004649
# 	 0 partial train loss (single batch): 0.004564
# 	 0 partial train loss (single batch): 0.004650
# 	 0 partial train loss (single batch): 0.004549
# 	 0 partial train loss (single batch): 0.004565
# 	 0 partial train loss (single batch): 0.004573
# 	 0 partial train loss (single batch): 0.004602
# 	 0 partial train loss (single batch): 0.004679
# 	 0 partial train loss (single batch): 0.004639
# 	 0 partial train loss (single batch): 0.004729
# 	 0 partial train loss (single batch): 0.004537
# 	 0 partial train loss (single batch): 0.004613
# 	 0 partial train loss (single batch): 0.004653
# 	 0 partial train loss (single batch): 0.004632
# 	 0 partial train loss (single batch): 0.004613
# 	 0 partial train loss (single batch): 0.004689
# 	 0 partial train loss (single batch): 0.004457
# 	 0 partial train loss (single batch): 0.004430
# 	 0 partial train loss (single batch): 0.004544
# 	 0 partial train loss (single batch): 0.004522
# 	 0 partial train loss (single batch): 0.004522
# 	 0 partial train loss (single batch): 0.004552
# 	 0 partial train loss (single batch): 0.004578
# 	 0 partial train loss (single batch): 0.004386
# 	 0 partial train loss (single batch): 0.004381
# 	 0 partial train loss (single batch): 0.004415
# 	 0 partial train loss (single batch): 0.004370
# 	 0 partial train loss (single batch): 0.004439
# 	 0 partial train loss (single batch): 0.004413
# 	 0 partial train loss (single batch): 0.004435
# 	 0 partial train loss (single batch): 0.004266
# 	 0 partial train loss (single batch): 0.004299
# 	 0 partial train loss (single batch): 0.004299
# 	 0 partial train loss (single batch): 0.004350
# 	 0 partial train loss (single batch): 0.004338
# 	 0 partial train loss (single batch): 0.004345
# 	 0 partial train loss (single batch): 0.004304
# 	 0 partial train loss (single batch): 0.004199
# 	 0 partial train loss (single batch): 0.004284
# 	 0 partial train loss (single batch): 0.004300
# 	 0 partial train loss (single batch): 0.004335
# 	 0 partial train loss (single batch): 0.004277
# 	 0 partial train loss (single batch): 0.004392
# 	 0 partial train loss (single batch): 0.004201
# 	 0 partial train loss (single batch): 0.004174
# 	 0 partial train loss (single batch): 0.004224
# 	 0 partial train loss (single batch): 0.004222
# 	 0 partial train loss (single batch): 0.004182
# 	 0 partial train loss (single batch): 0.004211
# 	 0 partial train loss (single batch): 0.004223
# 	 0 partial train loss (single batch): 0.004153
# 	 0 partial train loss (single batch): 0.004255
# 	 0 partial train loss (single batch): 0.004286
# 	 0 partial train loss (single batch): 0.004304
# 	 0 partial train loss (single batch): 0.004277
# 	 0 partial train loss (single batch): 0.004372
# 	 0 partial train loss (single batch): 0.004313
# 	 0 partial train loss (single batch): 0.004303
# 	 0 partial train loss (single batch): 0.004302
# 	 0 partial train loss (single batch): 0.004315
# 	 0 partial train loss (single batch): 0.004214
# 	 0 partial train loss (single batch): 0.004279
# 	 0 partial train loss (single batch): 0.004310
# 	 0 partial train loss (single batch): 0.004177
# 	 0 partial train loss (single batch): 0.004237
# 	 0 partial train loss (single batch): 0.004249
# 	 0 partial train loss (single batch): 0.004299
# 	 0 partial train loss (single batch): 0.004175
# 	 0 partial train loss (single batch): 0.004359
# 	 0 partial train loss (single batch): 0.004227
# 	 0 partial train loss (single batch): 0.004153
# 	 0 partial train loss (single batch): 0.004204
# 	 0 partial train loss (single batch): 0.004229
# 	 0 partial train loss (single batch): 0.004174
# 	 0 partial train loss (single batch): 0.004235
# 	 0 partial train loss (single batch): 0.004323
# 	 0 partial train loss (single batch): 0.004093
# 	 0 partial train loss (single batch): 0.004166
# 	 0 partial train loss (single batch): 0.004184
# 	 0 partial train loss (single batch): 0.004180
# 	 0 partial train loss (single batch): 0.004227
# 	 0 partial train loss (single batch): 0.004266
# 	 0 partial train loss (single batch): 0.004105
# 	 0 partial train loss (single batch): 0.004116
# 	 0 partial train loss (single batch): 0.004223
# 	 0 partial train loss (single batch): 0.004144
# 	 0 partial train loss (single batch): 0.004152
# 	 0 partial train loss (single batch): 0.004244
# 	 0 partial train loss (single batch): 0.004315
# 	 0 partial train loss (single batch): 0.004108
# 	 0 partial train loss (single batch): 0.004183
# 	 0 partial train loss (single batch): 0.004245
# 	 0 partial train loss (single batch): 0.004226
# 	 0 partial train loss (single batch): 0.004240
# 	 0 partial train loss (single batch): 0.004298
# 	 0 partial train loss (single batch): 0.004260
# 	 0 partial train loss (single batch): 0.004224
# 	 0 partial train loss (single batch): 0.004257
# 	 0 partial train loss (single batch): 0.004152
# 	 0 partial train loss (single batch): 0.004342
# 	 0 partial train loss (single batch): 0.004323
# 	 0 partial train loss (single batch): 0.004360
# 	 0 partial train loss (single batch): 0.004218
# 	 0 partial train loss (single batch): 0.004244
# 	 0 partial train loss (single batch): 0.004274
# 	 0 partial train loss (single batch): 0.004147
# 	 0 partial train loss (single batch): 0.004252
# 	 0 partial train loss (single batch): 0.004289
# 	 0 partial train loss (single batch): 0.004286
# 	 0 partial train loss (single batch): 0.004156
# 	 0 partial train loss (single batch): 0.004223
# 	 0 partial train loss (single batch): 0.004167
# 	 0 partial train loss (single batch): 0.004253
# 	 0 partial train loss (single batch): 0.004283
# 	 0 partial train loss (single batch): 0.004271
# 	 0 partial train loss (single batch): 0.004195
# 	 0 partial train loss (single batch): 0.004221
# 	 0 partial train loss (single batch): 0.004240
# 	 0 partial train loss (single batch): 0.004224
# 	 0 partial train loss (single batch): 0.004272
# 	 0 partial train loss (single batch): 0.004257
# 	 0 partial train loss (single batch): 0.004275
# 	 0 partial train loss (single batch): 0.004196
# 	 0 partial train loss (single batch): 0.004259
# 	 0 partial train loss (single batch): 0.004254
# 	 0 partial train loss (single batch): 0.004222
# 	 0 partial train loss (single batch): 0.004343
# 	 0 partial train loss (single batch): 0.004244
# 	 0 partial train loss (single batch): 0.004216
# 	 0 partial train loss (single batch): 0.004219
# 	 0 partial train loss (single batch): 0.004309
# 	 0 partial train loss (single batch): 0.004249
# 	 0 partial train loss (single batch): 0.004294
# 	 0 partial train loss (single batch): 0.004334
# 	 0 partial train loss (single batch): 0.004268
# 	 0 partial train loss (single batch): 0.004147
# 	 0 partial train loss (single batch): 0.004325
# 	 0 partial train loss (single batch): 0.004276
# 	 0 partial train loss (single batch): 0.004234
# 	 0 partial train loss (single batch): 0.004284
# 	 0 partial train loss (single batch): 0.004306
# 	 0 partial train loss (single batch): 0.004190
# 	 0 partial train loss (single batch): 0.004225
# 	 0 partial train loss (single batch): 0.004304
# 	 0 partial train loss (single batch): 0.004259
# 	 0 partial train loss (single batch): 0.004238
# 	 0 partial train loss (single batch): 0.004312
# 	 0 partial train loss (single batch): 0.004268
# 	 0 partial train loss (single batch): 0.004224
# 	 0 partial train loss (single batch): 0.004403
# 	 0 partial train loss (single batch): 0.004391
# 	 0 partial train loss (single batch): 0.004387
# 	 0 partial train loss (single batch): 0.004348
# 	 0 partial train loss (single batch): 0.004402
# 	 0 partial train loss (single batch): 0.004300
# 	 0 partial train loss (single batch): 0.004331
# 	 0 partial train loss (single batch): 0.004350
# 	 0 partial train loss (single batch): 0.004291
# 	 0 partial train loss (single batch): 0.004267
# 	 0 partial train loss (single batch): 0.004367
# 	 0 partial train loss (single batch): 0.004381
# 	 0 partial train loss (single batch): 0.004205
# 	 0 partial train loss (single batch): 0.004323
# 	 0 partial train loss (single batch): 0.004333
# 	 0 partial train loss (single batch): 0.004302
# 	 0 partial train loss (single batch): 0.004307
# 	 0 partial train loss (single batch): 0.004336
# 	 0 partial train loss (single batch): 0.004282
# 	 0 partial train loss (single batch): 0.004231
# 	 0 partial train loss (single batch): 0.004296
# 	 0 partial train loss (single batch): 0.004318
# 	 0 partial train loss (single batch): 0.004318
# 	 0 partial train loss (single batch): 0.004316
# 	 0 partial train loss (single batch): 0.004347
# 	 0 partial train loss (single batch): 0.004213
# 	 0 partial train loss (single batch): 0.004204
# 	 0 partial train loss (single batch): 0.004249
# 	 0 partial train loss (single batch): 0.004311
# 	 0 partial train loss (single batch): 0.004303
# 	 0 partial train loss (single batch): 0.004234
# 	 0 partial train loss (single batch): 0.004256
# 	 0 partial train loss (single batch): 0.004217
# 	 0 partial train loss (single batch): 0.004239
# 	 0 partial train loss (single batch): 0.004228
# 	 0 partial train loss (single batch): 0.004254
# 	 0 partial train loss (single batch): 0.004445
# 	 0 partial train loss (single batch): 0.004265
# 	 0 partial train loss (single batch): 0.004281
# 	 0 partial train loss (single batch): 0.004350
# 	 0 partial train loss (single batch): 0.004387
# 	 0 partial train loss (single batch): 0.004303
# 	 0 partial train loss (single batch): 0.004361
# 	 0 partial train loss (single batch): 0.004291
# 	 0 partial train loss (single batch): 0.004321
# 	 0 partial train loss (single batch): 0.004236
# 	 0 partial train loss (single batch): 0.004264
# 	 0 partial train loss (single batch): 0.004290
# 	 0 partial train loss (single batch): 0.004284
# 	 0 partial train loss (single batch): 0.004376
# 	 0 partial train loss (single batch): 0.004334
# 	 0 partial train loss (single batch): 0.004261
# 	 0 partial train loss (single batch): 0.004291
# 	 0 partial train loss (single batch): 0.004350
# 	 0 partial train loss (single batch): 0.004315
# 	 0 partial train loss (single batch): 0.004322
# 	 0 partial train loss (single batch): 0.004281
# 	 0 partial train loss (single batch): 0.004322
# 	 0 partial train loss (single batch): 0.004221
# 	 0 partial train loss (single batch): 0.004312
# 	 0 partial train loss (single batch): 0.004336
# 	 0 partial train loss (single batch): 0.004345
# 	 0 partial train loss (single batch): 0.004366
# 	 0 partial train loss (single batch): 0.004356
# 	 0 partial train loss (single batch): 0.004241
# 	 0 partial train loss (single batch): 0.004208
# 	 0 partial train loss (single batch): 0.004337
# 	 0 partial train loss (single batch): 0.004326
# 	 0 partial train loss (single batch): 0.004309
# 	 0 partial train loss (single batch): 0.004320
# 	 0 partial train loss (single batch): 0.004336
# 	 0 partial train loss (single batch): 0.004233
# 	 0 partial train loss (single batch): 0.004307
# 	 0 partial train loss (single batch): 0.004329
# 	 0 partial train loss (single batch): 0.004382
# 	 0 partial train loss (single batch): 0.004392
# 	 0 partial train loss (single batch): 0.004390
# 	 0 partial train loss (single batch): 0.004362
# 	 0 partial train loss (single batch): 0.004409
# 	 0 partial train loss (single batch): 0.004397
# 	 0 partial train loss (single batch): 0.004400
# 	 0 partial train loss (single batch): 0.004433
# 	 0 partial train loss (single batch): 0.004479
# 	 0 partial train loss (single batch): 0.004438
# 	 0 partial train loss (single batch): 0.004448
# 	 0 partial train loss (single batch): 0.004486
# 	 0 partial train loss (single batch): 0.004408
# 	 0 partial train loss (single batch): 0.004414
# 	 0 partial train loss (single batch): 0.004423
# 	 0 partial train loss (single batch): 0.004355
# 	 0 partial train loss (single batch): 0.004284
# 	 0 partial train loss (single batch): 0.004285
# 	 0 partial train loss (single batch): 0.004340
# 	 0 partial train loss (single batch): 0.004265
# 	 0 partial train loss (single batch): 0.004320
# 	 0 partial train loss (single batch): 0.004328
# 	 0 partial train loss (single batch): 0.004319
# 	 0 partial train loss (single batch): 0.004202
# 	 0 partial train loss (single batch): 0.004349
# 	 0 partial train loss (single batch): 0.004404
# 	 0 partial train loss (single batch): 0.004281
# 	 0 partial train loss (single batch): 0.004302
# 	 0 partial train loss (single batch): 0.004363
# 	 0 partial train loss (single batch): 0.004234
# 	 0 partial train loss (single batch): 0.004193
# 	 0 partial train loss (single batch): 0.004351
# 	 0 partial train loss (single batch): 0.004307
# 	 0 partial train loss (single batch): 0.004210
# 	 0 partial train loss (single batch): 0.019844
# 	 0 partial train loss (single batch): 0.002978
# 	 0 partial train loss (single batch): 0.003748
# 	 0 partial train loss (single batch): 0.003232
# 	 0 partial train loss (single batch): 0.002380
# 	 0 partial train loss (single batch): 0.002281
# 	 0 partial train loss (single batch): 0.002759
# 	 0 partial train loss (single batch): 0.002871
# 	 0 partial train loss (single batch): 0.002574
# 	 0 partial train loss (single batch): 0.002360
# 	 0 partial train loss (single batch): 0.002381
# 	 0 partial train loss (single batch): 0.002420
# 	 0 partial train loss (single batch): 0.002380
# 	 0 partial train loss (single batch): 0.002381
# 	 0 partial train loss (single batch): 0.002409
# 	 0 partial train loss (single batch): 0.002340
# 	 0 partial train loss (single batch): 0.002234
# 	 0 partial train loss (single batch): 0.002172
# 	 0 partial train loss (single batch): 0.002274
# 	 0 partial train loss (single batch): 0.002369
# 	 0 partial train loss (single batch): 0.002328
# 	 0 partial train loss (single batch): 0.002201
# 	 0 partial train loss (single batch): 0.002130
# 	 0 partial train loss (single batch): 0.002189
# 	 0 partial train loss (single batch): 0.002253
# 	 0 partial train loss (single batch): 0.002200
# 	 0 partial train loss (single batch): 0.002139
# 	 0 partial train loss (single batch): 0.002103
# 	 0 partial train loss (single batch): 0.002100
# 	 0 partial train loss (single batch): 0.002119
# ...
# 	 9 partial train loss (single batch): 0.004100
# 	 9 partial train loss (single batch): 0.004030
# 	 9 partial train loss (single batch): 0.004114
# 	 9 partial train loss (single batch): 0.004182
# 	 9 partial train loss (single batch): 0.004013
# 	 9 partial train loss (single batch): 0.004048
# 	 9 partial train loss (single batch): 0.004061
# 	 9 partial train loss (single batch): 0.004066
# 	 9 partial train loss (single batch): 0.004015
# 	 9 partial train loss (single batch): 0.003990
# 	 9 partial train loss (single batch): 0.003904
# 	 9 partial train loss (single batch): 0.003890
# 	 9 partial train loss (single batch): 0.003902
# 	 9 partial train loss (single batch): 0.004156
# 	 9 partial train loss (single batch): 0.004068
# 	 9 partial train loss (single batch): 0.004274
# 	 9 partial train loss (single batch): 0.004436
# 	 9 partial train loss (single batch): 0.004533
# 	 9 partial train loss (single batch): 0.004663
# 	 9 partial train loss (single batch): 0.004568
# 	 9 partial train loss (single batch): 0.004404
# 	 9 partial train loss (single batch): 0.004394
# 	 9 partial train loss (single batch): 0.004525
# 	 9 partial train loss (single batch): 0.004387
# 	 9 partial train loss (single batch): 0.004392
# 	 9 partial train loss (single batch): 0.004261
# 	 9 partial train loss (single batch): 0.004372
# 	 9 partial train loss (single batch): 0.004528
# 	 9 partial train loss (single batch): 0.004620
# 	 9 partial train loss (single batch): 0.004591
# 	 9 partial train loss (single batch): 0.004759
# 	 9 partial train loss (single batch): 0.004729
# 	 9 partial train loss (single batch): 0.004557
# 	 9 partial train loss (single batch): 0.004447
# 	 9 partial train loss (single batch): 0.004422
# 	 9 partial train loss (single batch): 0.004487
# 	 9 partial train loss (single batch): 0.004658
# 	 9 partial train loss (single batch): 0.004777
# 	 9 partial train loss (single batch): 0.004539
# 	 9 partial train loss (single batch): 0.005260
# 	 9 partial train loss (single batch): 0.004945
# 	 9 partial train loss (single batch): 0.012413
# 	 9 partial train loss (single batch): 0.004672
# 	 9 partial train loss (single batch): 0.004730
# 	 9 partial train loss (single batch): 0.005628
# 	 9 partial train loss (single batch): 0.004715
# 	 9 partial train loss (single batch): 0.004356
# 	 9 partial train loss (single batch): 0.004547
# 	 9 partial train loss (single batch): 0.004534
# 	 9 partial train loss (single batch): 0.004535
# 	 9 partial train loss (single batch): 0.004999
# 	 9 partial train loss (single batch): 0.005477
# 	 9 partial train loss (single batch): 0.005089
# 	 9 partial train loss (single batch): 0.004869
# 	 9 partial train loss (single batch): 0.004900
# 	 9 partial train loss (single batch): 0.005024
# 	 9 partial train loss (single batch): 0.005928
# 	 9 partial train loss (single batch): 0.007037
# 	 9 partial train loss (single batch): 0.006481
# 	 9 partial train loss (single batch): 0.009572
# 	 9 partial train loss (single batch): 0.008512
# 	 9 partial train loss (single batch): 0.006331
# 	 9 partial train loss (single batch): 0.006446
# 	 9 partial train loss (single batch): 0.007188
# 	 9 partial train loss (single batch): 0.004576
# 	 9 partial train loss (single batch): 0.004665
# 	 9 partial train loss (single batch): 0.003610
# 	 9 partial train loss (single batch): 0.004260
# 	 9 partial train loss (single batch): 0.003894
# 	 9 partial train loss (single batch): 0.004149
# 	 9 partial train loss (single batch): 0.005327
# 	 9 partial train loss (single batch): 0.004211
# 	 9 partial train loss (single batch): 0.003248
# 	 9 partial train loss (single batch): 0.003848
# 	 9 partial train loss (single batch): 0.003538
# 	 9 partial train loss (single batch): 0.003405
# 	 9 partial train loss (single batch): 0.003752
# 	 9 partial train loss (single batch): 0.003799
# 	 9 partial train loss (single batch): 0.002929
# 	 9 partial train loss (single batch): 0.002620
# 	 9 partial train loss (single batch): 0.002965
# 	 9 partial train loss (single batch): 0.002839
# 	 9 partial train loss (single batch): 0.003108
# 	 9 partial train loss (single batch): 0.003060
# 	 9 partial train loss (single batch): 0.001930
# 	 9 partial train loss (single batch): 0.001925
# 	 9 partial train loss (single batch): 0.002579
# 	 9 partial train loss (single batch): 0.002482
# 	 9 partial train loss (single batch): 0.003055
# 	 9 partial train loss (single batch): 0.003632
# 	 9 partial train loss (single batch): 0.005780
# 	 9 partial train loss (single batch): 0.002808
# 	 9 partial train loss (single batch): 0.002382
# 	 9 partial train loss (single batch): 0.002503
# 	 9 partial train loss (single batch): 0.001675
# 	 9 partial train loss (single batch): 0.001375
# 	 9 partial train loss (single batch): 0.001324
# 	 9 partial train loss (single batch): 0.000937
# 	 9 partial train loss (single batch): 0.000912
# 	 9 partial train loss (single batch): 0.000935
# 	 9 partial train loss (single batch): 0.000769
# 	 9 partial train loss (single batch): 0.001142
# 	 9 partial train loss (single batch): 0.000941
# 	 9 partial train loss (single batch): 0.000821
# 	 9 partial train loss (single batch): 0.000847
# 	 9 partial train loss (single batch): 0.000932
# 	 9 partial train loss (single batch): 0.000921
# 	 9 partial train loss (single batch): 0.000792
# 	 9 partial train loss (single batch): 0.001388
# 	 9 partial train loss (single batch): 0.000952
# 	 9 partial train loss (single batch): 0.000930
# 	 9 partial train loss (single batch): 0.000718
# 	 9 partial train loss (single batch): 0.000788
# 	 9 partial train loss (single batch): 0.000980
# 	 9 partial train loss (single batch): 0.001882
# 	 9 partial train loss (single batch): 0.002342
# 	 9 partial train loss (single batch): 0.003099
# 	 9 partial train loss (single batch): 0.000865
# 	 9 partial train loss (single batch): 0.000855
# 	 9 partial train loss (single batch): 0.000723
# 	 9 partial train loss (single batch): 0.000575
# 	 9 partial train loss (single batch): 0.000572
# 	 9 partial train loss (single batch): 0.000650
# 	 9 partial train loss (single batch): 0.000561
# 	 9 partial train loss (single batch): 0.000572
# 	 9 partial train loss (single batch): 0.000476
# 	 9 partial train loss (single batch): 0.000513
# 	 9 partial train loss (single batch): 0.000467
# 	 9 partial train loss (single batch): 0.000476
# 	 9 partial train loss (single batch): 0.000581
# 	 9 partial train loss (single batch): 0.000826
# 	 9 partial train loss (single batch): 0.000815
# 	 9 partial train loss (single batch): 0.001030
# 	 9 partial train loss (single batch): 0.000846
# 	 9 partial train loss (single batch): 0.001241
# 	 9 partial train loss (single batch): 0.000656
# 	 9 partial train loss (single batch): 0.000539
# 	 9 partial train loss (single batch): 0.000722
# 	 9 partial train loss (single batch): 0.000542
# 	 9 partial train loss (single batch): 0.000477
# 	 9 partial train loss (single batch): 0.000409
# 	 9 partial train loss (single batch): 0.000358
# 	 9 partial train loss (single batch): 0.000324
# 	 9 partial train loss (single batch): 0.003518
# 	 9 partial train loss (single batch): 0.003734
# 	 9 partial train loss (single batch): 0.003775
# 	 9 partial train loss (single batch): 0.003832
# 	 9 partial train loss (single batch): 0.003818
# 	 9 partial train loss (single batch): 0.003570
# 	 9 partial train loss (single batch): 0.004138
# 	 9 partial train loss (single batch): 0.003678
# 	 9 partial train loss (single batch): 0.003539
# 	 9 partial train loss (single batch): 0.003098
# 	 9 partial train loss (single batch): 0.003379
# 	 9 partial train loss (single batch): 0.003335
# 	 9 partial train loss (single batch): 0.003378
# 	 9 partial train loss (single batch): 0.003534
# 	 9 partial train loss (single batch): 0.003145
# 	 9 partial train loss (single batch): 0.003674
# 	 9 partial train loss (single batch): 0.003510
# 	 9 partial train loss (single batch): 0.003307
# 	 9 partial train loss (single batch): 0.003246
# 	 9 partial train loss (single batch): 0.003518
# 	 9 partial train loss (single batch): 0.002874
# 	 9 partial train loss (single batch): 0.002940
# 	 9 partial train loss (single batch): 0.003316
# 	 9 partial train loss (single batch): 0.002917
# 	 9 partial train loss (single batch): 0.003232
# 	 9 partial train loss (single batch): 0.003031
# 	 9 partial train loss (single batch): 0.003069
# 	 9 partial train loss (single batch): 0.002905
# 	 9 partial train loss (single batch): 0.002927
# 	 9 partial train loss (single batch): 0.002883
# 	 9 partial train loss (single batch): 0.002795
# 	 9 partial train loss (single batch): 0.002898
# 	 9 partial train loss (single batch): 0.003080
# 	 9 partial train loss (single batch): 0.003464
# 	 9 partial train loss (single batch): 0.003017
# 	 9 partial train loss (single batch): 0.002952
# 	 9 partial train loss (single batch): 0.002910
# 	 9 partial train loss (single batch): 0.002806
# 	 9 partial train loss (single batch): 0.002850
# 	 9 partial train loss (single batch): 0.002752
# 	 9 partial train loss (single batch): 0.002842
# 	 9 partial train loss (single batch): 0.002927
# 	 9 partial train loss (single batch): 0.002964
# 	 9 partial train loss (single batch): 0.003006
# 	 9 partial train loss (single batch): 0.002951
# 	 9 partial train loss (single batch): 0.002990
# 	 9 partial train loss (single batch): 0.002839
# 	 9 partial train loss (single batch): 0.002810
# 	 9 partial train loss (single batch): 0.002654
# 	 9 partial train loss (single batch): 0.002761
# 	 9 partial train loss (single batch): 0.002801
# 	 9 partial train loss (single batch): 0.002768
# 	 9 partial train loss (single batch): 0.002928
# 	 9 partial train loss (single batch): 0.002876
# 	 9 partial train loss (single batch): 0.002822
# 	 9 partial train loss (single batch): 0.002791
# 	 9 partial train loss (single batch): 0.002759
# 	 9 partial train loss (single batch): 0.002674
# 	 9 partial train loss (single batch): 0.002726
# 	 9 partial train loss (single batch): 0.002840
# 	 9 partial train loss (single batch): 0.002777
# 	 9 partial train loss (single batch): 0.002752
# 	 9 partial train loss (single batch): 0.002660
# 	 9 partial train loss (single batch): 0.002723
# 	 9 partial train loss (single batch): 0.002625
# 	 9 partial train loss (single batch): 0.002662
# 	 9 partial train loss (single batch): 0.002618
# 	 9 partial train loss (single batch): 0.002554
# 	 9 partial train loss (single batch): 0.002663
# 	 9 partial train loss (single batch): 0.002677
# 	 9 partial train loss (single batch): 0.002679
# 	 9 partial train loss (single batch): 0.002634
# 	 9 partial train loss (single batch): 0.002587
# 	 9 partial train loss (single batch): 0.002602
# 	 9 partial train loss (single batch): 0.002516
# 	 9 partial train loss (single batch): 0.002514
# 	 9 partial train loss (single batch): 0.002478
# 	 9 partial train loss (single batch): 0.002543
# 	 9 partial train loss (single batch): 0.002610
# 	 9 partial train loss (single batch): 0.002500
# 	 9 partial train loss (single batch): 0.002630
# 	 9 partial train loss (single batch): 0.002551
# 	 9 partial train loss (single batch): 0.002421
# 	 9 partial train loss (single batch): 0.002352
# 	 9 partial train loss (single batch): 0.002418
# 	 9 partial train loss (single batch): 0.002348
# 	 9 partial train loss (single batch): 0.002318
# 	 9 partial train loss (single batch): 0.002422
# 	 9 partial train loss (single batch): 0.002351
# 	 9 partial train loss (single batch): 0.002455
# 	 9 partial train loss (single batch): 0.002377
# 	 9 partial train loss (single batch): 0.002417
# 	 9 partial train loss (single batch): 0.002381
# 	 9 partial train loss (single batch): 0.002354
# 	 9 partial train loss (single batch): 0.002421
# 	 9 partial train loss (single batch): 0.002341
# 	 9 partial train loss (single batch): 0.002387
# 	 9 partial train loss (single batch): 0.002345
# 	 9 partial train loss (single batch): 0.002375
# 	 9 partial train loss (single batch): 0.002372
# 	 9 partial train loss (single batch): 0.002357
# 	 9 partial train loss (single batch): 0.002343
# 	 9 partial train loss (single batch): 0.002404
# 	 9 partial train loss (single batch): 0.002369
# 	 9 partial train loss (single batch): 0.002300
# 	 9 partial train loss (single batch): 0.002433
# 	 9 partial train loss (single batch): 0.002398
# 	 9 partial train loss (single batch): 0.002370
# 	 9 partial train loss (single batch): 0.002447
# 	 9 partial train loss (single batch): 0.002356
# 	 9 partial train loss (single batch): 0.002307
# 	 9 partial train loss (single batch): 0.002361
# 	 9 partial train loss (single batch): 0.002302
# 	 9 partial train loss (single batch): 0.002281
# 	 9 partial train loss (single batch): 0.002363
# 	 9 partial train loss (single batch): 0.002349
# 	 9 partial train loss (single batch): 0.002347
# 	 9 partial train loss (single batch): 0.002417
# 	 9 partial train loss (single batch): 0.002333
# 	 9 partial train loss (single batch): 0.002304
# 	 9 partial train loss (single batch): 0.002373
# 	 9 partial train loss (single batch): 0.002315
# 	 9 partial train loss (single batch): 0.002274
# 	 9 partial train loss (single batch): 0.002347
# 	 9 partial train loss (single batch): 0.002312
# 	 9 partial train loss (single batch): 0.002278
# 	 9 partial train loss (single batch): 0.002354
# 	 9 partial train loss (single batch): 0.002295
# 	 9 partial train loss (single batch): 0.002309
# 	 9 partial train loss (single batch): 0.002369
# 	 9 partial train loss (single batch): 0.002327
# 	 9 partial train loss (single batch): 0.002285
# 	 9 partial train loss (single batch): 0.002345
# 	 9 partial train loss (single batch): 0.002315
# 	 9 partial train loss (single batch): 0.002395
# 	 9 partial train loss (single batch): 0.002329
# 	 9 partial train loss (single batch): 0.002353
# 	 9 partial train loss (single batch): 0.002324
# 	 9 partial train loss (single batch): 0.002294
# 	 9 partial train loss (single batch): 0.002332
# 	 9 partial train loss (single batch): 0.002300
# 	 9 partial train loss (single batch): 0.002261
# 	 9 partial train loss (single batch): 0.002329
# 	 9 partial train loss (single batch): 0.002297
# 	 9 partial train loss (single batch): 0.002282
# 	 9 partial train loss (single batch): 0.002309
# 	 9 partial train loss (single batch): 0.002250
# 	 9 partial train loss (single batch): 0.002314
# 	 9 partial train loss (single batch): 0.002307
# 	 9 partial train loss (single batch): 0.002278
# 	 9 partial train loss (single batch): 0.002604
# 	 9 partial train loss (single batch): 0.003054
# 	 9 partial train loss (single batch): 0.005114
# 	 9 partial train loss (single batch): 0.008188
# 	 9 partial train loss (single batch): 0.006532
# 	 9 partial train loss (single batch): 0.005250
# 	 9 partial train loss (single batch): 0.005614
# 	 9 partial train loss (single batch): 0.005654
# 	 9 partial train loss (single batch): 0.004243
# 	 9 partial train loss (single batch): 0.004261
# 	 9 partial train loss (single batch): 0.003778
# 	 9 partial train loss (single batch): 0.005288
# 	 9 partial train loss (single batch): 0.006624
# 	 9 partial train loss (single batch): 0.005708
# 	 9 partial train loss (single batch): 0.004367
# 	 9 partial train loss (single batch): 0.004453
# 	 9 partial train loss (single batch): 0.004739
# 	 9 partial train loss (single batch): 0.003606
# 	 9 partial train loss (single batch): 0.003607
# 	 9 partial train loss (single batch): 0.003747
# 	 9 partial train loss (single batch): 0.003005
# 	 9 partial train loss (single batch): 0.003212
# 	 9 partial train loss (single batch): 0.004035
# 	 9 partial train loss (single batch): 0.003744
# 	 9 partial train loss (single batch): 0.003135
# 	 9 partial train loss (single batch): 0.003246
# 	 9 partial train loss (single batch): 0.002968
# 	 9 partial train loss (single batch): 0.002844
# 	 9 partial train loss (single batch): 0.003430
# 	 9 partial train loss (single batch): 0.002936
# 	 9 partial train loss (single batch): 0.002697
# 	 9 partial train loss (single batch): 0.003191
# 	 9 partial train loss (single batch): 0.003278
# 	 9 partial train loss (single batch): 0.002491
# 	 9 partial train loss (single batch): 0.002845
# 	 9 partial train loss (single batch): 0.003379
# 	 9 partial train loss (single batch): 0.002713
# 	 9 partial train loss (single batch): 0.003153
# 	 9 partial train loss (single batch): 0.003067
# 	 9 partial train loss (single batch): 0.002640

# %%
videoDataLoader = VideoDataLoader(VIDEOS_SKI_TEST)
fps = videoDataLoader.videos[0]["fps"]
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
# out = cv2.VideoWriter('24fpsFromModel.mp4', fourcc, fps, (width, height), isColor=True)
autoencoder.eval()
i = 0
with torch.no_grad():
    test_loss = []
    while videoDataLoader.hasNext():
        batch = videoDataLoader.getNext()
        first_f = np.transpose(batch[0].numpy(), (1, 2, 0))
        original_f = np.transpose(batch[1].numpy(), (1, 2, 0))

        first_frame = batch[0].to(device)
        middle_frame = batch[1].to(device)
        last_frame = batch[2].to(device)

        res_frame = autoencoder(first_frame, last_frame)
        # image_np = torchvision.transforms.functional.invert(res_frame.cpu().data).numpy()
        middle_f = np.transpose(res_frame.cpu().data.numpy(), (1, 2, 0))
        cv2.imshow('generated frame', cv2.hconcat([first_f, first_f]))
        cv2.imshow('generated frame', cv2.hconcat([first_f, middle_f]))
        # out.write(cv2.hconcat([first_f, first_f]))
        # out.write(cv2.hconcat([first_f, middle_f]))
        # out.write(first_f)
        # out.write(middle_f)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

        loss = loss_fn(res_frame, middle_frame)
        print('\t %d partial test loss (single batch): %f' % (i, loss.data))
        i = i + 1
        test_loss.append(loss.detach().cpu().numpy())
    cv2.destroyAllWindows()
# out.release()
# Out:
# 	 0 partial test loss (single batch): 0.015459
# 	 1 partial test loss (single batch): 0.015469
# 	 2 partial test loss (single batch): 0.015116
# 	 3 partial test loss (single batch): 0.014673
# 	 4 partial test loss (single batch): 0.014595
# 	 5 partial test loss (single batch): 0.014959
# 	 6 partial test loss (single batch): 0.017008
# 	 7 partial test loss (single batch): 0.020824
# 	 8 partial test loss (single batch): 0.021248
# 	 9 partial test loss (single batch): 0.020254
# 	 10 partial test loss (single batch): 0.017925
# 	 11 partial test loss (single batch): 0.015959
# 	 12 partial test loss (single batch): 0.014515
# 	 13 partial test loss (single batch): 0.014320
# 	 14 partial test loss (single batch): 0.013801
# 	 15 partial test loss (single batch): 0.013829
# 	 16 partial test loss (single batch): 0.014609
# 	 17 partial test loss (single batch): 0.015271
# 	 18 partial test loss (single batch): 0.015427
# 	 19 partial test loss (single batch): 0.015177
# 	 20 partial test loss (single batch): 0.014783
# 	 21 partial test loss (single batch): 0.014483
# 	 22 partial test loss (single batch): 0.013864
# 	 23 partial test loss (single batch): 0.013262
# 	 24 partial test loss (single batch): 0.012929
# 	 25 partial test loss (single batch): 0.012781
# 	 26 partial test loss (single batch): 0.012813
# 	 27 partial test loss (single batch): 0.012489
# 	 28 partial test loss (single batch): 0.012413
# 	 29 partial test loss (single batch): 0.012122
# 	 30 partial test loss (single batch): 0.011111
# 	 31 partial test loss (single batch): 0.010904
# 	 32 partial test loss (single batch): 0.009946
# 	 33 partial test loss (single batch): 0.009934
# 	 34 partial test loss (single batch): 0.009217
# 	 35 partial test loss (single batch): 0.008813
# 	 36 partial test loss (single batch): 0.008515
# 	 37 partial test loss (single batch): 0.008410
# 	 38 partial test loss (single batch): 0.008294
# 	 39 partial test loss (single batch): 0.007826
# 	 40 partial test loss (single batch): 0.008304
# 	 41 partial test loss (single batch): 0.008098
# 	 42 partial test loss (single batch): 0.007559
# 	 43 partial test loss (single batch): 0.007949
# 	 44 partial test loss (single batch): 0.008183
# 	 45 partial test loss (single batch): 0.008303
# 	 46 partial test loss (single batch): 0.008146
# 	 47 partial test loss (single batch): 0.007948
# 	 48 partial test loss (single batch): 0.008035
# 	 49 partial test loss (single batch): 0.008102
# 	 50 partial test loss (single batch): 0.008153
# 	 51 partial test loss (single batch): 0.007812
# 	 52 partial test loss (single batch): 0.008482
# 	 53 partial test loss (single batch): 0.008479
# 	 54 partial test loss (single batch): 0.008671
# 	 55 partial test loss (single batch): 0.008157
# 	 56 partial test loss (single batch): 0.008385
# 	 57 partial test loss (single batch): 0.008453
# 	 58 partial test loss (single batch): 0.008148
# 	 59 partial test loss (single batch): 0.008231
# 	 60 partial test loss (single batch): 0.007883
# 	 61 partial test loss (single batch): 0.007336
# 	 62 partial test loss (single batch): 0.007346
# 	 63 partial test loss (single batch): 0.006872
# 	 64 partial test loss (single batch): 0.006929
# 	 65 partial test loss (single batch): 0.007267
# 	 66 partial test loss (single batch): 0.007014
# 	 67 partial test loss (single batch): 0.006614
# 	 68 partial test loss (single batch): 0.005873
# 	 69 partial test loss (single batch): 0.005447
# 	 70 partial test loss (single batch): 0.005262
# 	 71 partial test loss (single batch): 0.005347
# 	 72 partial test loss (single batch): 0.005296
# 	 73 partial test loss (single batch): 0.005002
# 	 74 partial test loss (single batch): 0.005190
# 	 75 partial test loss (single batch): 0.004963
# 	 76 partial test loss (single batch): 0.004869
# 	 77 partial test loss (single batch): 0.005234
# 	 78 partial test loss (single batch): 0.005319
# 	 79 partial test loss (single batch): 0.005259
# 	 80 partial test loss (single batch): 0.005540
# 	 81 partial test loss (single batch): 0.005678
# 	 82 partial test loss (single batch): 0.005591
# 	 83 partial test loss (single batch): 0.005715
# 	 84 partial test loss (single batch): 0.005676
# 	 85 partial test loss (single batch): 0.006065
# 	 86 partial test loss (single batch): 0.006138
# 	 87 partial test loss (single batch): 0.006587
# 	 88 partial test loss (single batch): 0.008041
# 	 89 partial test loss (single batch): 0.008951
# 	 90 partial test loss (single batch): 0.009786
# 	 91 partial test loss (single batch): 0.010850
# 	 92 partial test loss (single batch): 0.011869
# 	 93 partial test loss (single batch): 0.012701
# 	 94 partial test loss (single batch): 0.014280
# 	 95 partial test loss (single batch): 0.015337
# 	 96 partial test loss (single batch): 0.017255
# 	 97 partial test loss (single batch): 0.016831
# 	 98 partial test loss (single batch): 0.018877
# 	 99 partial test loss (single batch): 0.019063
# 	 100 partial test loss (single batch): 0.019648
# 	 101 partial test loss (single batch): 0.018400
# 	 102 partial test loss (single batch): 0.017560
# 	 103 partial test loss (single batch): 0.016062
# 	 104 partial test loss (single batch): 0.015591
# 	 105 partial test loss (single batch): 0.015920
# 	 106 partial test loss (single batch): 0.014849
# 	 107 partial test loss (single batch): 0.014558
# 	 108 partial test loss (single batch): 0.016007
# 	 109 partial test loss (single batch): 0.016817
# 	 110 partial test loss (single batch): 0.017471
# 	 111 partial test loss (single batch): 0.017780
# 	 112 partial test loss (single batch): 0.015077
# 	 113 partial test loss (single batch): 0.014708
# 	 114 partial test loss (single batch): 0.014920
# 	 115 partial test loss (single batch): 0.014468
# 	 116 partial test loss (single batch): 0.014628
# 	 117 partial test loss (single batch): 0.016218
# 	 118 partial test loss (single batch): 0.017649
# 	 119 partial test loss (single batch): 0.018067
# 	 120 partial test loss (single batch): 0.019051
# 	 121 partial test loss (single batch): 0.020372
# 	 122 partial test loss (single batch): 0.021618
# 	 123 partial test loss (single batch): 0.021774
# 	 124 partial test loss (single batch): 0.022985
# 	 125 partial test loss (single batch): 0.022072
# 	 126 partial test loss (single batch): 0.019433
# 	 127 partial test loss (single batch): 0.017872
# 	 128 partial test loss (single batch): 0.018109
# 	 129 partial test loss (single batch): 0.018192
# 	 130 partial test loss (single batch): 0.018855
# 	 131 partial test loss (single batch): 0.019835
# 	 132 partial test loss (single batch): 0.019295
# 	 133 partial test loss (single batch): 0.018022
# 	 134 partial test loss (single batch): 0.017100
# 	 135 partial test loss (single batch): 0.017195
# 	 136 partial test loss (single batch): 0.018106
# 	 137 partial test loss (single batch): 0.019214
# 	 138 partial test loss (single batch): 0.020901
# 	 139 partial test loss (single batch): 0.020697
# 	 140 partial test loss (single batch): 0.016279
# 	 141 partial test loss (single batch): 0.014050
# 	 142 partial test loss (single batch): 0.013060
# 	 143 partial test loss (single batch): 0.012601
# 	 144 partial test loss (single batch): 0.012893
# 	 145 partial test loss (single batch): 0.013058
# 	 146 partial test loss (single batch): 0.012128
# 	 147 partial test loss (single batch): 0.011950
# 	 148 partial test loss (single batch): 0.012565
# 	 149 partial test loss (single batch): 0.013421
# 	 150 partial test loss (single batch): 0.013296
# 	 151 partial test loss (single batch): 0.013375
# 	 152 partial test loss (single batch): 0.014512
# 	 153 partial test loss (single batch): 0.014724
# 	 154 partial test loss (single batch): 0.014304
# 	 155 partial test loss (single batch): 0.014064
# 	 156 partial test loss (single batch): 0.014189
# 	 157 partial test loss (single batch): 0.014577
# 	 158 partial test loss (single batch): 0.014954
# 	 159 partial test loss (single batch): 0.016140
# 	 160 partial test loss (single batch): 0.016311
# 	 161 partial test loss (single batch): 0.015939
# 	 162 partial test loss (single batch): 0.014809
# 	 163 partial test loss (single batch): 0.014321
# 	 164 partial test loss (single batch): 0.014288
# 	 165 partial test loss (single batch): 0.014520
# 	 166 partial test loss (single batch): 0.014829
# 	 167 partial test loss (single batch): 0.014310
# 	 168 partial test loss (single batch): 0.013770
# 	 169 partial test loss (single batch): 0.012876
# 	 170 partial test loss (single batch): 0.011548
# 	 171 partial test loss (single batch): 0.011418
# 	 172 partial test loss (single batch): 0.011546
# 	 173 partial test loss (single batch): 0.011591
# 	 174 partial test loss (single batch): 0.011020
# 	 175 partial test loss (single batch): 0.011369
# 	 176 partial test loss (single batch): 0.011899
# 	 177 partial test loss (single batch): 0.012168
# 	 178 partial test loss (single batch): 0.011658
# 	 179 partial test loss (single batch): 0.011438
# 	 180 partial test loss (single batch): 0.011369
# 	 181 partial test loss (single batch): 0.011244
# 	 182 partial test loss (single batch): 0.011137
# 	 183 partial test loss (single batch): 0.011563
# 	 184 partial test loss (single batch): 0.011697
# 	 185 partial test loss (single batch): 0.012038
# 	 186 partial test loss (single batch): 0.012463
# 	 187 partial test loss (single batch): 0.012505
# 	 188 partial test loss (single batch): 0.011771
# 	 189 partial test loss (single batch): 0.010036
# 	 190 partial test loss (single batch): 0.008535
# 	 191 partial test loss (single batch): 0.008193
# 	 192 partial test loss (single batch): 0.008389
# 	 193 partial test loss (single batch): 0.008278
# 	 194 partial test loss (single batch): 0.007517
# 	 195 partial test loss (single batch): 0.006459
# 	 196 partial test loss (single batch): 0.005723
# 	 197 partial test loss (single batch): 0.005671
# 	 198 partial test loss (single batch): 0.005749
# 	 199 partial test loss (single batch): 0.005670
# 	 200 partial test loss (single batch): 0.005828
# 	 201 partial test loss (single batch): 0.005764
# 	 202 partial test loss (single batch): 0.005615
# 	 203 partial test loss (single batch): 0.005516
# 	 204 partial test loss (single batch): 0.005369
# 	 205 partial test loss (single batch): 0.005461
# 	 206 partial test loss (single batch): 0.005503
# 	 207 partial test loss (single batch): 0.005287
# 	 208 partial test loss (single batch): 0.005486
# 	 209 partial test loss (single batch): 0.004782
# 	 210 partial test loss (single batch): 0.004755
# 	 211 partial test loss (single batch): 0.004333
# 	 212 partial test loss (single batch): 0.004640
# 	 213 partial test loss (single batch): 0.004990
# 	 214 partial test loss (single batch): 0.006899
# 	 215 partial test loss (single batch): 0.009190
# 	 216 partial test loss (single batch): 0.007061
# 	 217 partial test loss (single batch): 0.006315
# 	 218 partial test loss (single batch): 0.004395
# 	 219 partial test loss (single batch): 0.003293
# 	 220 partial test loss (single batch): 0.003553
# 	 221 partial test loss (single batch): 0.003426
# 	 222 partial test loss (single batch): 0.003526
# 	 223 partial test loss (single batch): 0.003248
# 	 224 partial test loss (single batch): 0.003431
# 	 225 partial test loss (single batch): 0.003153
# 	 226 partial test loss (single batch): 0.003408
# 	 227 partial test loss (single batch): 0.003099
# 	 228 partial test loss (single batch): 0.003340
# 	 229 partial test loss (single batch): 0.003092
# 	 230 partial test loss (single batch): 0.003290
# 	 231 partial test loss (single batch): 0.003037
# 	 232 partial test loss (single batch): 0.003317
# 	 233 partial test loss (single batch): 0.003082
# 	 234 partial test loss (single batch): 0.003275
# 	 235 partial test loss (single batch): 0.002978
# 	 236 partial test loss (single batch): 0.003192
# 	 237 partial test loss (single batch): 0.002951
# 	 238 partial test loss (single batch): 0.003198
# 	 239 partial test loss (single batch): 0.002904
# 	 240 partial test loss (single batch): 0.003155
# 	 241 partial test loss (single batch): 0.002930
# 	 242 partial test loss (single batch): 0.003191
# 	 243 partial test loss (single batch): 0.002844
# 	 244 partial test loss (single batch): 0.003053
# 	 245 partial test loss (single batch): 0.002745
# 	 246 partial test loss (single batch): 0.002872
# 	 247 partial test loss (single batch): 0.002613
# 	 248 partial test loss (single batch): 0.002824
# 	 249 partial test loss (single batch): 0.002581
# 	 250 partial test loss (single batch): 0.002790
# 	 251 partial test loss (single batch): 0.002614
# 	 252 partial test loss (single batch): 0.002828
# 	 253 partial test loss (single batch): 0.002606
# 	 254 partial test loss (single batch): 0.002875
# 	 255 partial test loss (single batch): 0.002615
# 	 256 partial test loss (single batch): 0.002873
# 	 257 partial test loss (single batch): 0.002644
# 	 258 partial test loss (single batch): 0.002849
# 	 259 partial test loss (single batch): 0.002628
# 	 260 partial test loss (single batch): 0.002859
# 	 261 partial test loss (single batch): 0.002666
# 	 262 partial test loss (single batch): 0.002872
# 	 263 partial test loss (single batch): 0.002702
# 	 264 partial test loss (single batch): 0.002964
# 	 265 partial test loss (single batch): 0.002728
# 	 266 partial test loss (single batch): 0.002915
# 	 267 partial test loss (single batch): 0.002688
# 	 268 partial test loss (single batch): 0.002908
# 	 269 partial test loss (single batch): 0.002709
# 	 270 partial test loss (single batch): 0.002905
# 	 271 partial test loss (single batch): 0.002700
# 	 272 partial test loss (single batch): 0.002943
# 	 273 partial test loss (single batch): 0.002695
# 	 274 partial test loss (single batch): 0.002920
# 	 275 partial test loss (single batch): 0.002726
# 	 276 partial test loss (single batch): 0.002964
# 	 277 partial test loss (single batch): 0.002815
# 	 278 partial test loss (single batch): 0.003049
# 	 279 partial test loss (single batch): 0.002848
# 	 280 partial test loss (single batch): 0.003064
# 	 281 partial test loss (single batch): 0.002800
# 	 282 partial test loss (single batch): 0.003024
# 	 283 partial test loss (single batch): 0.002799
# 	 284 partial test loss (single batch): 0.003025
# 	 285 partial test loss (single batch): 0.002800
# 	 286 partial test loss (single batch): 0.003024
# 	 287 partial test loss (single batch): 0.002815
# 	 288 partial test loss (single batch): 0.003050
# 	 289 partial test loss (single batch): 0.002812
# 	 290 partial test loss (single batch): 0.003036
# 	 291 partial test loss (single batch): 0.002791
# 	 292 partial test loss (single batch): 0.003088
# 	 293 partial test loss (single batch): 0.002879
# 	 294 partial test loss (single batch): 0.003152
# 	 295 partial test loss (single batch): 0.002931
# 	 296 partial test loss (single batch): 0.003166
# 	 297 partial test loss (single batch): 0.002989
# 	 298 partial test loss (single batch): 0.003263
# 	 299 partial test loss (single batch): 0.003074
# 	 300 partial test loss (single batch): 0.003245
# 	 301 partial test loss (single batch): 0.003060
# 	 302 partial test loss (single batch): 0.003240
# 	 303 partial test loss (single batch): 0.003118
# 	 304 partial test loss (single batch): 0.003471
# 	 305 partial test loss (single batch): 0.003441
# 	 306 partial test loss (single batch): 0.003371
# 	 307 partial test loss (single batch): 0.003317
# 	 308 partial test loss (single batch): 0.001411
# 	 309 partial test loss (single batch): 0.001406
# 	 310 partial test loss (single batch): 0.001397
# 	 311 partial test loss (single batch): 0.001407
# 	 312 partial test loss (single batch): 0.001391
# 	 313 partial test loss (single batch): 0.001396
# 	 314 partial test loss (single batch): 0.001385
# 	 315 partial test loss (single batch): 0.001381
# 	 316 partial test loss (single batch): 0.001375
# 	 317 partial test loss (single batch): 0.001374
# 	 318 partial test loss (single batch): 0.001363
# 	 319 partial test loss (single batch): 0.001358
# 	 320 partial test loss (single batch): 0.001360
# 	 321 partial test loss (single batch): 0.001359
# 	 322 partial test loss (single batch): 0.001344
# 	 323 partial test loss (single batch): 0.001363
# 	 324 partial test loss (single batch): 0.001389
# 	 325 partial test loss (single batch): 0.001357
# 	 326 partial test loss (single batch): 0.001397
# 	 327 partial test loss (single batch): 0.001397
# 	 328 partial test loss (single batch): 0.001388
# 	 329 partial test loss (single batch): 0.001400
# 	 330 partial test loss (single batch): 0.001395
# 	 331 partial test loss (single batch): 0.001394
# 	 332 partial test loss (single batch): 0.001391
# 	 333 partial test loss (single batch): 0.001389
# 	 334 partial test loss (single batch): 0.001393
# 	 335 partial test loss (single batch): 0.001401
# 	 336 partial test loss (single batch): 0.001400
# 	 337 partial test loss (single batch): 0.001415
# 	 338 partial test loss (single batch): 0.001419
# 	 339 partial test loss (single batch): 0.001433
# 	 340 partial test loss (single batch): 0.001442
# 	 341 partial test loss (single batch): 0.001451
# 	 342 partial test loss (single batch): 0.001454
# 	 343 partial test loss (single batch): 0.001483
# 	 344 partial test loss (single batch): 0.001484
# 	 345 partial test loss (single batch): 0.001487
# 	 346 partial test loss (single batch): 0.001493
# 	 347 partial test loss (single batch): 0.001479
# 	 348 partial test loss (single batch): 0.001488
# 	 349 partial test loss (single batch): 0.001474
# 	 350 partial test loss (single batch): 0.001475
# 	 351 partial test loss (single batch): 0.001469
# 	 352 partial test loss (single batch): 0.001470
# 	 353 partial test loss (single batch): 0.001464
# 	 354 partial test loss (single batch): 0.001476
# 	 355 partial test loss (single batch): 0.001474
# 	 356 partial test loss (single batch): 0.001473
# 	 357 partial test loss (single batch): 0.001465
# 	 358 partial test loss (single batch): 0.001470
# 	 359 partial test loss (single batch): 0.001466
# 	 360 partial test loss (single batch): 0.001471
# 	 361 partial test loss (single batch): 0.001483
# 	 362 partial test loss (single batch): 0.001493
# 	 363 partial test loss (single batch): 0.001481
# 	 364 partial test loss (single batch): 0.001507
# 	 365 partial test loss (single batch): 0.001494
# 	 366 partial test loss (single batch): 0.001483
# 	 367 partial test loss (single batch): 0.001483
# 	 368 partial test loss (single batch): 0.001481
# 	 369 partial test loss (single batch): 0.001476
# 	 370 partial test loss (single batch): 0.001476
# 	 371 partial test loss (single batch): 0.001477
# 	 372 partial test loss (single batch): 0.001476
# 	 373 partial test loss (single batch): 0.001445
# 	 374 partial test loss (single batch): 0.001465
# 	 375 partial test loss (single batch): 0.001432
# 	 376 partial test loss (single batch): 0.001465
# 	 377 partial test loss (single batch): 0.001468
# 	 378 partial test loss (single batch): 0.001468
# 	 379 partial test loss (single batch): 0.001469
# 	 380 partial test loss (single batch): 0.001465
# 	 381 partial test loss (single batch): 0.001459
# 	 382 partial test loss (single batch): 0.001461
# 	 383 partial test loss (single batch): 0.001459
# 	 384 partial test loss (single batch): 0.001489
# 	 385 partial test loss (single batch): 0.001484
# 	 386 partial test loss (single batch): 0.001481
# 	 387 partial test loss (single batch): 0.001496
# 	 388 partial test loss (single batch): 0.001542
# 	 389 partial test loss (single batch): 0.001575
# 	 390 partial test loss (single batch): 0.001568
# 	 391 partial test loss (single batch): 0.001592
# 	 392 partial test loss (single batch): 0.001631
# 	 393 partial test loss (single batch): 0.001677
# 	 394 partial test loss (single batch): 0.001662
# 	 395 partial test loss (single batch): 0.001641
# 	 396 partial test loss (single batch): 0.001641
# 	 397 partial test loss (single batch): 0.001673
# 	 398 partial test loss (single batch): 0.001651
# 	 399 partial test loss (single batch): 0.001585
# 	 400 partial test loss (single batch): 0.001555
# 	 401 partial test loss (single batch): 0.001536
# 	 402 partial test loss (single batch): 0.001527
# 	 403 partial test loss (single batch): 0.001444
# 	 404 partial test loss (single batch): 0.001391
# 	 405 partial test loss (single batch): 0.001386
# 	 406 partial test loss (single batch): 0.001383
# 	 407 partial test loss (single batch): 0.001368
# 	 408 partial test loss (single batch): 0.001356
# 	 409 partial test loss (single batch): 0.001344
# 	 410 partial test loss (single batch): 0.001349
# 	 411 partial test loss (single batch): 0.001344
# 	 412 partial test loss (single batch): 0.001346
# 	 413 partial test loss (single batch): 0.001334
# 	 414 partial test loss (single batch): 0.001331
# 	 415 partial test loss (single batch): 0.001329
# 	 416 partial test loss (single batch): 0.001327
# 	 417 partial test loss (single batch): 0.001328
# 	 418 partial test loss (single batch): 0.001325
# 	 419 partial test loss (single batch): 0.001323
# 	 420 partial test loss (single batch): 0.001321
# 	 421 partial test loss (single batch): 0.001322
# 	 422 partial test loss (single batch): 0.001320
# 	 423 partial test loss (single batch): 0.001329
# 	 424 partial test loss (single batch): 0.001327
# 	 425 partial test loss (single batch): 0.001332
# 	 426 partial test loss (single batch): 0.001332
# 	 427 partial test loss (single batch): 0.001322
# 	 428 partial test loss (single batch): 0.001325
# 	 429 partial test loss (single batch): 0.001328
# 	 430 partial test loss (single batch): 0.001323
# 	 431 partial test loss (single batch): 0.001319
# 	 432 partial test loss (single batch): 0.001300
# 	 433 partial test loss (single batch): 0.001363
# 	 434 partial test loss (single batch): 0.001351
# 	 435 partial test loss (single batch): 0.001333
# 	 436 partial test loss (single batch): 0.001335
# 	 437 partial test loss (single batch): 0.001321
# 	 438 partial test loss (single batch): 0.001307
# 	 439 partial test loss (single batch): 0.001314
# 	 440 partial test loss (single batch): 0.001329
# 	 441 partial test loss (single batch): 0.001338
# 	 442 partial test loss (single batch): 0.001307
# 	 443 partial test loss (single batch): 0.001298
# 	 444 partial test loss (single batch): 0.001304
# 	 445 partial test loss (single batch): 0.001315
# 	 446 partial test loss (single batch): 0.001331
# 	 447 partial test loss (single batch): 0.001351
# 	 448 partial test loss (single batch): 0.001360
# 	 449 partial test loss (single batch): 0.001369
# 	 450 partial test loss (single batch): 0.001366
# 	 451 partial test loss (single batch): 0.001347
# 	 452 partial test loss (single batch): 0.001367
# 	 453 partial test loss (single batch): 0.001371
# 	 454 partial test loss (single batch): 0.001346
# 	 455 partial test loss (single batch): 0.001357
# 	 456 partial test loss (single batch): 0.001337
# 	 457 partial test loss (single batch): 0.001365
# 	 458 partial test loss (single batch): 0.001351
# 	 459 partial test loss (single batch): 0.001335
# 	 460 partial test loss (single batch): 0.001333
# 	 461 partial test loss (single batch): 0.001352
# 	 462 partial test loss (single batch): 0.001324
# 	 463 partial test loss (single batch): 0.001331
# 	 464 partial test loss (single batch): 0.001331
# 	 465 partial test loss (single batch): 0.001346
# 	 466 partial test loss (single batch): 0.001326
# 	 467 partial test loss (single batch): 0.001323
# 	 468 partial test loss (single batch): 0.001314
# 	 469 partial test loss (single batch): 0.001329
# 	 470 partial test loss (single batch): 0.001326
# 	 471 partial test loss (single batch): 0.001305
# 	 472 partial test loss (single batch): 0.001295
# 	 473 partial test loss (single batch): 0.001304
# 	 474 partial test loss (single batch): 0.001285
# 	 475 partial test loss (single batch): 0.001282
# 	 476 partial test loss (single batch): 0.001285
# 	 477 partial test loss (single batch): 0.001284
# 	 478 partial test loss (single batch): 0.001279
# 	 479 partial test loss (single batch): 0.001270
# 	 480 partial test loss (single batch): 0.001253
# 	 481 partial test loss (single batch): 0.001247
# 	 482 partial test loss (single batch): 0.001239
# 	 483 partial test loss (single batch): 0.001249
# 	 484 partial test loss (single batch): 0.001234
# 	 485 partial test loss (single batch): 0.001238
# 	 486 partial test loss (single batch): 0.001229
# 	 487 partial test loss (single batch): 0.001235
# 	 488 partial test loss (single batch): 0.001246
# 	 489 partial test loss (single batch): 0.001243
# 	 490 partial test loss (single batch): 0.001233
# 	 491 partial test loss (single batch): 0.001236
# 	 492 partial test loss (single batch): 0.001227
# 	 493 partial test loss (single batch): 0.001254
# 	 494 partial test loss (single batch): 0.001247
# 	 495 partial test loss (single batch): 0.001254
# 	 496 partial test loss (single batch): 0.001251
# 	 497 partial test loss (single batch): 0.001240
# 	 498 partial test loss (single batch): 0.001227
# 	 499 partial test loss (single batch): 0.001236
# 	 500 partial test loss (single batch): 0.001229
# 	 501 partial test loss (single batch): 0.001240
# 	 502 partial test loss (single batch): 0.001245
# 	 503 partial test loss (single batch): 0.001239
# 	 504 partial test loss (single batch): 0.001248
# 	 505 partial test loss (single batch): 0.001253
# 	 506 partial test loss (single batch): 0.001244
# 	 507 partial test loss (single batch): 0.001253
# 	 508 partial test loss (single batch): 0.001247
# 	 509 partial test loss (single batch): 0.001257
# 	 510 partial test loss (single batch): 0.001257
# 	 511 partial test loss (single batch): 0.001248
# 	 512 partial test loss (single batch): 0.001237
# 	 513 partial test loss (single batch): 0.001255
# 	 514 partial test loss (single batch): 0.001269
# 	 515 partial test loss (single batch): 0.001260
# 	 516 partial test loss (single batch): 0.001264
# 	 517 partial test loss (single batch): 0.001264
# 	 518 partial test loss (single batch): 0.001288
# 	 519 partial test loss (single batch): 0.001293
# 	 520 partial test loss (single batch): 0.001292
# 	 521 partial test loss (single batch): 0.001297
# 	 522 partial test loss (single batch): 0.001300
# 	 523 partial test loss (single batch): 0.001307
# 	 524 partial test loss (single batch): 0.001300
# 	 525 partial test loss (single batch): 0.001294
# 	 526 partial test loss (single batch): 0.001300
# 	 527 partial test loss (single batch): 0.001292
# 	 528 partial test loss (single batch): 0.001298
# 	 529 partial test loss (single batch): 0.001427
# 	 530 partial test loss (single batch): 0.001474
# 	 531 partial test loss (single batch): 0.001484
# 	 532 partial test loss (single batch): 0.001591
# 	 533 partial test loss (single batch): 0.001823
# 	 534 partial test loss (single batch): 0.001705
# 	 535 partial test loss (single batch): 0.001840
# 	 536 partial test loss (single batch): 0.001642
# 	 537 partial test loss (single batch): 0.001472
# 	 538 partial test loss (single batch): 0.001394
# 	 539 partial test loss (single batch): 0.001364
# 	 540 partial test loss (single batch): 0.001346
# 	 541 partial test loss (single batch): 0.001351
# 	 542 partial test loss (single batch): 0.001369
# 	 543 partial test loss (single batch): 0.001385
# 	 544 partial test loss (single batch): 0.001387
# 	 545 partial test loss (single batch): 0.001377
# 	 546 partial test loss (single batch): 0.001387
# 	 547 partial test loss (single batch): 0.001403
# 	 548 partial test loss (single batch): 0.001395
# 	 549 partial test loss (single batch): 0.001402
# 	 550 partial test loss (single batch): 0.001395
# 	 551 partial test loss (single batch): 0.001373
# 	 552 partial test loss (single batch): 0.001364
# 	 553 partial test loss (single batch): 0.001366
# 	 554 partial test loss (single batch): 0.001364
# 	 555 partial test loss (single batch): 0.001388
# 	 556 partial test loss (single batch): 0.001389
# 	 557 partial test loss (single batch): 0.001412
# 	 558 partial test loss (single batch): 0.001498
# 	 559 partial test loss (single batch): 0.001510
# 	 560 partial test loss (single batch): 0.001480
# 	 561 partial test loss (single batch): 0.001473
# 	 562 partial test loss (single batch): 0.001444
# 	 563 partial test loss (single batch): 0.001431
# 	 564 partial test loss (single batch): 0.001415
# 	 565 partial test loss (single batch): 0.001422
# 	 566 partial test loss (single batch): 0.001411
# 	 567 partial test loss (single batch): 0.001466
# 	 568 partial test loss (single batch): 0.001509
# 	 569 partial test loss (single batch): 0.001556
# 	 570 partial test loss (single batch): 0.001579
# 	 571 partial test loss (single batch): 0.001606
# 	 572 partial test loss (single batch): 0.001637
# 	 573 partial test loss (single batch): 0.001670
# 	 574 partial test loss (single batch): 0.001663
# 	 575 partial test loss (single batch): 0.001665
# 	 576 partial test loss (single batch): 0.001660
# 	 577 partial test loss (single batch): 0.001584
# 	 578 partial test loss (single batch): 0.001577
# 	 579 partial test loss (single batch): 0.001497
# 	 580 partial test loss (single batch): 0.001463
# 	 581 partial test loss (single batch): 0.001407
# 	 582 partial test loss (single batch): 0.001436
# 	 583 partial test loss (single batch): 0.001445
# 	 584 partial test loss (single batch): 0.001465
# 	 585 partial test loss (single batch): 0.001438
# 	 586 partial test loss (single batch): 0.001426
# 	 587 partial test loss (single batch): 0.001414
# 	 588 partial test loss (single batch): 0.001432
# 	 589 partial test loss (single batch): 0.001434
# 	 590 partial test loss (single batch): 0.001469
# 	 591 partial test loss (single batch): 0.001465
# 	 592 partial test loss (single batch): 0.001497
# 	 593 partial test loss (single batch): 0.001480
# 	 594 partial test loss (single batch): 0.001554
# 	 595 partial test loss (single batch): 0.001580
# 	 596 partial test loss (single batch): 0.001628
# 	 597 partial test loss (single batch): 0.001557
# 	 598 partial test loss (single batch): 0.001492
# 	 599 partial test loss (single batch): 0.001428
# 	 600 partial test loss (single batch): 0.001473
# 	 601 partial test loss (single batch): 0.001452
# 	 602 partial test loss (single batch): 0.001427
# 	 603 partial test loss (single batch): 0.001416
# 	 604 partial test loss (single batch): 0.001429
# 	 605 partial test loss (single batch): 0.001415
# 	 606 partial test loss (single batch): 0.001455
# 	 607 partial test loss (single batch): 0.001480
# 	 608 partial test loss (single batch): 0.001532
# 	 609 partial test loss (single batch): 0.001539
# 	 610 partial test loss (single batch): 0.001558
# 	 611 partial test loss (single batch): 0.001586
# 	 612 partial test loss (single batch): 0.001797
# 	 613 partial test loss (single batch): 0.002029
# 	 614 partial test loss (single batch): 0.002282
# 	 615 partial test loss (single batch): 0.002436
# 	 616 partial test loss (single batch): 0.002635
# 	 617 partial test loss (single batch): 0.002725
# 	 618 partial test loss (single batch): 0.002755
# 	 619 partial test loss (single batch): 0.002756
# 	 620 partial test loss (single batch): 0.002947
# 	 621 partial test loss (single batch): 0.003031
# 	 622 partial test loss (single batch): 0.003000
# 	 623 partial test loss (single batch): 0.002750
# 	 624 partial test loss (single batch): 0.002497
# 	 625 partial test loss (single batch): 0.002214
# 	 626 partial test loss (single batch): 0.002103
# 	 627 partial test loss (single batch): 0.001965
# 	 628 partial test loss (single batch): 0.001917
# 	 629 partial test loss (single batch): 0.001827
# 	 630 partial test loss (single batch): 0.001891
# 	 631 partial test loss (single batch): 0.001776
# 	 632 partial test loss (single batch): 0.001702
# 	 633 partial test loss (single batch): 0.001599
# 	 634 partial test loss (single batch): 0.001597
# 	 635 partial test loss (single batch): 0.001572
# 	 636 partial test loss (single batch): 0.001603
# 	 637 partial test loss (single batch): 0.001562
# 	 638 partial test loss (single batch): 0.001599
# 	 639 partial test loss (single batch): 0.001556
# 	 640 partial test loss (single batch): 0.001593
# 	 641 partial test loss (single batch): 0.001575
# 	 642 partial test loss (single batch): 0.001586
# 	 643 partial test loss (single batch): 0.001571
# 	 644 partial test loss (single batch): 0.001609
# 	 645 partial test loss (single batch): 0.001792
# 	 646 partial test loss (single batch): 0.002245
# 	 647 partial test loss (single batch): 0.002243
# 	 648 partial test loss (single batch): 0.002261
# 	 649 partial test loss (single batch): 0.002031
# 	 650 partial test loss (single batch): 0.001873
# 	 651 partial test loss (single batch): 0.001765
# 	 652 partial test loss (single batch): 0.001745
# 	 653 partial test loss (single batch): 0.001666
# 	 654 partial test loss (single batch): 0.001684
# 	 655 partial test loss (single batch): 0.001641
# 	 656 partial test loss (single batch): 0.001701
# 	 657 partial test loss (single batch): 0.001733
# 	 658 partial test loss (single batch): 0.001875
# 	 659 partial test loss (single batch): 0.001916
# 	 660 partial test loss (single batch): 0.002022
# 	 661 partial test loss (single batch): 0.002106
# 	 662 partial test loss (single batch): 0.002685
# 	 663 partial test loss (single batch): 0.003531
# 	 664 partial test loss (single batch): 0.004413
# 	 665 partial test loss (single batch): 0.004846
# 	 666 partial test loss (single batch): 0.005235
# 	 667 partial test loss (single batch): 0.004570
# 	 668 partial test loss (single batch): 0.003808
# 	 669 partial test loss (single batch): 0.003415
# 	 670 partial test loss (single batch): 0.003097
# 	 671 partial test loss (single batch): 0.002729
# 	 672 partial test loss (single batch): 0.002779
# 	 673 partial test loss (single batch): 0.002679
# 	 674 partial test loss (single batch): 0.002499
# 	 675 partial test loss (single batch): 0.002094
# 	 676 partial test loss (single batch): 0.002030
# 	 677 partial test loss (single batch): 0.002150
# 	 678 partial test loss (single batch): 0.002385
# 	 679 partial test loss (single batch): 0.002533
# 	 680 partial test loss (single batch): 0.002357
# 	 681 partial test loss (single batch): 0.001981
# 	 682 partial test loss (single batch): 0.001847
# 	 683 partial test loss (single batch): 0.002679
# 	 684 partial test loss (single batch): 0.004624
# 	 685 partial test loss (single batch): 0.007265
# 	 686 partial test loss (single batch): 0.011868
# 	 687 partial test loss (single batch): 0.011893
# 	 688 partial test loss (single batch): 0.009566
# 	 689 partial test loss (single batch): 0.008455
# 	 690 partial test loss (single batch): 0.009169
# 	 691 partial test loss (single batch): 0.007296
# 	 692 partial test loss (single batch): 0.003816
# 	 693 partial test loss (single batch): 0.002698
# 	 694 partial test loss (single batch): 0.002377
# 	 695 partial test loss (single batch): 0.002266
# 	 696 partial test loss (single batch): 0.001961
# 	 697 partial test loss (single batch): 0.001825
# 	 698 partial test loss (single batch): 0.001732
# 	 699 partial test loss (single batch): 0.001687
# 	 700 partial test loss (single batch): 0.001728
# 	 701 partial test loss (single batch): 0.001780
# 	 702 partial test loss (single batch): 0.001593
# 	 703 partial test loss (single batch): 0.001590
# 	 704 partial test loss (single batch): 0.001586
# 	 705 partial test loss (single batch): 0.001580
# 	 706 partial test loss (single batch): 0.001586
# 	 707 partial test loss (single batch): 0.001588
# 	 708 partial test loss (single batch): 0.001583
# 	 709 partial test loss (single batch): 0.001593
# 	 710 partial test loss (single batch): 0.001599
# 	 711 partial test loss (single batch): 0.001599
# 	 712 partial test loss (single batch): 0.001593
# 	 713 partial test loss (single batch): 0.001592
# 	 714 partial test loss (single batch): 0.001596
# 	 715 partial test loss (single batch): 0.001587
# 	 716 partial test loss (single batch): 0.001589
# 	 717 partial test loss (single batch): 0.001595
# 	 718 partial test loss (single batch): 0.001589
# 	 719 partial test loss (single batch): 0.001587
# 	 720 partial test loss (single batch): 0.001592
# 	 721 partial test loss (single batch): 0.001595
# 	 722 partial test loss (single batch): 0.001588
# 	 723 partial test loss (single batch): 0.001577
# 	 724 partial test loss (single batch): 0.001577
# 	 725 partial test loss (single batch): 0.001581
# 	 726 partial test loss (single batch): 0.001578
# 	 727 partial test loss (single batch): 0.001586
# 	 728 partial test loss (single batch): 0.001576
# 	 729 partial test loss (single batch): 0.001595
# 	 730 partial test loss (single batch): 0.001588
# 	 731 partial test loss (single batch): 0.001587
# 	 732 partial test loss (single batch): 0.001590
# 	 733 partial test loss (single batch): 0.001600
# 	 734 partial test loss (single batch): 0.001596
# 	 735 partial test loss (single batch): 0.001599
# 	 736 partial test loss (single batch): 0.001597
# 	 737 partial test loss (single batch): 0.001612
# 	 738 partial test loss (single batch): 0.001590
# 	 739 partial test loss (single batch): 0.001590
# 	 740 partial test loss (single batch): 0.001578
# 	 741 partial test loss (single batch): 0.001593
# 	 742 partial test loss (single batch): 0.001578
# 	 743 partial test loss (single batch): 0.001570
# 	 744 partial test loss (single batch): 0.001582
# 	 745 partial test loss (single batch): 0.001583
# 	 746 partial test loss (single batch): 0.001550
# 	 747 partial test loss (single batch): 0.001507
# 	 748 partial test loss (single batch): 0.001503
# 	 749 partial test loss (single batch): 0.001480
# 	 750 partial test loss (single batch): 0.001472
# 	 751 partial test loss (single batch): 0.001510
# 	 752 partial test loss (single batch): 0.001512
# 	 753 partial test loss (single batch): 0.001519
# 	 754 partial test loss (single batch): 0.001507
# 	 755 partial test loss (single batch): 0.001505
# 	 756 partial test loss (single batch): 0.001501
# 	 757 partial test loss (single batch): 0.001481
# 	 758 partial test loss (single batch): 0.001490
# 	 759 partial test loss (single batch): 0.001469
# 	 760 partial test loss (single batch): 0.001507
# 	 761 partial test loss (single batch): 0.001480
# 	 762 partial test loss (single batch): 0.001494
# 	 763 partial test loss (single batch): 0.001473
# 	 764 partial test loss (single batch): 0.001497
# 	 765 partial test loss (single batch): 0.001466
# 	 766 partial test loss (single batch): 0.001486
# 	 767 partial test loss (single batch): 0.001462
# 	 768 partial test loss (single batch): 0.001482
# 	 769 partial test loss (single batch): 0.001447
# 	 770 partial test loss (single batch): 0.001470
# 	 771 partial test loss (single batch): 0.001455
# 	 772 partial test loss (single batch): 0.001465
# 	 773 partial test loss (single batch): 0.001444
# 	 774 partial test loss (single batch): 0.001466
# 	 775 partial test loss (single batch): 0.001442
# 	 776 partial test loss (single batch): 0.001467
# 	 777 partial test loss (single batch): 0.001442
# 	 778 partial test loss (single batch): 0.001466
# 	 779 partial test loss (single batch): 0.001449
# 	 780 partial test loss (single batch): 0.001462
# 	 781 partial test loss (single batch): 0.001443
# 	 782 partial test loss (single batch): 0.001458
# 	 783 partial test loss (single batch): 0.001432
# 	 784 partial test loss (single batch): 0.001444
# 	 785 partial test loss (single batch): 0.001415
# 	 786 partial test loss (single batch): 0.001450
# 	 787 partial test loss (single batch): 0.001426
# 	 788 partial test loss (single batch): 0.001453
# 	 789 partial test loss (single batch): 0.001422
# 	 790 partial test loss (single batch): 0.001456
# 	 791 partial test loss (single batch): 0.001429
# 	 792 partial test loss (single batch): 0.001448
# 	 793 partial test loss (single batch): 0.001441
# 	 794 partial test loss (single batch): 0.001456
# 	 795 partial test loss (single batch): 0.001450
# 	 796 partial test loss (single batch): 0.001464
# 	 797 partial test loss (single batch): 0.001443
# 	 798 partial test loss (single batch): 0.001463
# 	 799 partial test loss (single batch): 0.001439
# 	 800 partial test loss (single batch): 0.001467
# 	 801 partial test loss (single batch): 0.001444
# 	 802 partial test loss (single batch): 0.001473
# 	 803 partial test loss (single batch): 0.001442
# 	 804 partial test loss (single batch): 0.001467
# 	 805 partial test loss (single batch): 0.001448
# 	 806 partial test loss (single batch): 0.001473
# 	 807 partial test loss (single batch): 0.001455
# 	 808 partial test loss (single batch): 0.001507
# 	 809 partial test loss (single batch): 0.001515
# 	 810 partial test loss (single batch): 0.001503
# 	 811 partial test loss (single batch): 0.001516
# 	 812 partial test loss (single batch): 0.001513
# 	 813 partial test loss (single batch): 0.001537
# 	 814 partial test loss (single batch): 0.001534
# 	 815 partial test loss (single batch): 0.001539
# 	 816 partial test loss (single batch): 0.001531
# 	 817 partial test loss (single batch): 0.001538
# 	 818 partial test loss (single batch): 0.001540
# 	 819 partial test loss (single batch): 0.001551
# 	 820 partial test loss (single batch): 0.001537
# 	 821 partial test loss (single batch): 0.001541
# 	 822 partial test loss (single batch): 0.001536
# 	 823 partial test loss (single batch): 0.001543
# 	 824 partial test loss (single batch): 0.001533
# 	 825 partial test loss (single batch): 0.001538
# 	 826 partial test loss (single batch): 0.001544
# 	 827 partial test loss (single batch): 0.001535
# 	 828 partial test loss (single batch): 0.001523
# 	 829 partial test loss (single batch): 0.001531
# 	 830 partial test loss (single batch): 0.001524
# 	 831 partial test loss (single batch): 0.001516
# 	 832 partial test loss (single batch): 0.001504
# 	 833 partial test loss (single batch): 0.001506
# 	 834 partial test loss (single batch): 0.001497
# 	 835 partial test loss (single batch): 0.001500
# 	 836 partial test loss (single batch): 0.001503
# 	 837 partial test loss (single batch): 0.001513
# 	 838 partial test loss (single batch): 0.001504
# 	 839 partial test loss (single batch): 0.001517
# 	 840 partial test loss (single batch): 0.001531
# 	 841 partial test loss (single batch): 0.001535
# 	 842 partial test loss (single batch): 0.001520
# 	 843 partial test loss (single batch): 0.001535
# 	 844 partial test loss (single batch): 0.001551
